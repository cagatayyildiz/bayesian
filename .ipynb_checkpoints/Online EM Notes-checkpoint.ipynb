# %% [markdown]
# # An Application of Online EM Algorithm to Letter Prediction Problem

# %% [markdown]
# The implementation of HMM in large part belongs to Ali Taylan Cemgil(ATC):
# https://github.com/atcemgil/notes/blob/master/HiddenMarkovModel.ipynb
#
# The code importing the data also belongs to ATC: https://github.com/atcemgil/notes/blob/master/Sampling.ipynb

# %% [markdown]
# ## An Implementation of HMM in Python

# %% [markdown]
# ### Some Utility Functions

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def randgen(pr, N=1): 
    L = len(pr)
    return np.random.choice(range(L), size=N, replace=True, p=pr)

def log_sum_exp(l, axis=0):
    l_star = np.max(l, axis=axis, keepdims=True)
    return l_star + np.log(np.sum(np.exp(l - l_star),axis=axis,keepdims=True)) 

def normalize_exp(log_P, axis=None):
    a = np.max(log_P, keepdims=True, axis=axis)
    P = normalize(np.exp(log_P - a), axis=axis)
    return P

def normalize(A, axis=None):
    Z = np.sum(A, axis=axis,keepdims=True)
    idx = np.where(Z == 0)
    Z[idx] = 1
    return A/Z

# %% [markdown]
# ### Some HMM Functions

# %%
def predict(A, lp):
    lstar = np.max(lp)
    return lstar + np.log(np.dot(A,np.exp(lp-lstar)))

def postdict(A, lp):
    lstar = np.max(lp)
    return lstar + np.log(np.dot(np.exp(lp-lstar), A))

def update(y, logB, lp):
    return logB[y,:] + lp

# %% [markdown]
# ### HMM Implementation

# %%
class HMM(object):
    def __init__(self, pi, A, B):
        # p(x_0)
        self.pi = pi
        # p(x_k|x_{k-1})
        self.A = A
        # p(y_k|x_{k})
        self.B = B
        # Number of possible latent states at each time
        self.S = pi.shape[0]
        # Number of possible observations at each time
        self.R = B.shape[0]
        self.logB = np.log(self.B)
        self.logA = np.log(self.A)
        self.logpi = np.log(self.pi)
        
    def copy(self):
        pi_ = self.pi.copy()
        A_ = self.A.copy()
        B_ = self.B.copy()
        hmm = HMM(pi_,A_,B_)
        return hmm
    
    @classmethod
    def from_random_parameters(cls, S=3, R=5):
        A = np.random.dirichlet(0.7*np.ones(S),S).T
        B = np.random.dirichlet(0.7*np.ones(R),S).T
        pi = np.random.dirichlet(0.7*np.ones(S)).T
        return cls(pi, A, B)
        
    def __str__(self):
        s = "Prior:\n" + str(self.pi) + "\nA:\n" + str(self.A) + "\nB:\n" + str(self.B)
        return s
    
    def __repr__(self):
        s = self.__str__()
        return s

    def predict(self, lp):
        lstar = np.max(lp)
        return lstar + np.log(np.dot(self.A,np.exp(lp-lstar)))

    def postdict(self, lp):
        lstar = np.max(lp)
        return lstar + np.log(np.dot(np.exp(lp-lstar), self.A))

    def update(self, y, lp):
        return self.logB[y,:] + lp

    def generate_sequence(self, T=10):
        # T: Number of steps
        x = np.zeros(T)
        y = np.zeros(T)

        for t in range(T):
            if t==0:
                x[t] = randgen(self.pi)
            else:
                x[t] = randgen(self.A[:,x[t-1]])    
            y[t] = randgen(self.B[:,x[t]])
    
        return y, x

    def forward(self, y):
        T = len(y)
        
        # Forward Pass

        # Python indexes starting from zero so
        # log \alpha_{k|k} will be in log_alpha[:,k-1]
        # log \alpha_{k|k-1} will be in log_alpha_pred[:,k-1]
        log_alpha  = np.zeros((self.S, T))
        log_alpha_pred = np.zeros((self.S, T))
        for k in range(T):
            if k==0:
                log_alpha_pred[:,0] = self.logpi
            else:
                log_alpha_pred[:,k] = self.predict(log_alpha[:,k-1])

            log_alpha[:,k] = self.update(y[k], log_alpha_pred[:,k])
            
        return log_alpha, log_alpha_pred
            
    def backward(self, y):
        # Backward Pass
        T = len(y)
        log_beta  = np.zeros((self.S, T))
        log_beta_post = np.zeros((self.S, T))

        for k in range(T-1,-1,-1):
            if k==T-1:
                log_beta_post[:,k] = np.zeros(self.S)
            else:
                log_beta_post[:,k] = self.postdict(log_beta[:,k+1])

            log_beta[:,k] = self.update(y[k], log_beta_post[:,k])

        return log_beta, log_beta_post
        
    def forward_backward_smoother(self, y):
        log_alpha, log_alpha_pred = self.forward(y)
        log_beta, log_beta_post = self.backward(y)
        
        log_gamma = log_alpha + log_beta_post
        return log_gamma
        
    def correction_smoother(self, y):
        # Correction Smoother

        log_alpha, log_alpha_pred = self.forward(y)
        T = len(y)
        
        # For numerical stability, we calculate everything in the log domain
        log_gamma_corr = np.zeros_like(log_alpha)
        log_gamma_corr[:,T-1] = log_alpha[:,T-1]

        C2 = np.zeros((self.S, self.S))
        C3 = np.zeros((self.R, self.S))
        C3[y[-1],:] = normalize_exp(log_alpha[:,T-1])
        for k in range(T-2,-1,-1):
            log_old_pairwise_marginal = log_alpha[:,k].reshape(1,self.S) + self.logA 
            log_old_marginal = self.predict(log_alpha[:,k])
            log_new_pairwise_marginal = log_old_pairwise_marginal + log_gamma_corr[:,k+1].reshape(self.S,1) - log_old_marginal.reshape(self.S,1)
            log_gamma_corr[:,k] = log_sum_exp(log_new_pairwise_marginal, axis=0).reshape(self.S)
            C2 += normalize_exp(log_new_pairwise_marginal)
            C3[y[k],:] += normalize_exp(log_gamma_corr[:,k])
        C1 = normalize_exp(log_gamma_corr[:,0])
        return C1, C2, C3, log_gamma_corr
    
    def forward_only_SS(self, y, V=None):
        # Forward only estimation of expected sufficient statistics
        T = len(y)
        
        if V is None:
            V1  = np.eye((self.S))
            V2  = np.zeros((self.S,self.S,self.S))
            V3  = np.zeros((self.R,self.S,self.S))
        else:
            V1, V2, V3 = V
            
        I_S1S = np.eye(self.S).reshape((self.S,1,self.S))
        I_RR = np.eye(self.R)
        
        for k in range(T):
            if k==0:
                log_alpha_pred = self.logpi
            else:
                log_alpha_pred = self.predict(log_alpha)

            if k>0:
                #print(self.S, self.R)
                #print(log_alpha)
                # Calculate p(x_{k-1}|y_{1:k-1}, x_k) 
                lp = np.log(normalize_exp(log_alpha)).reshape(self.S,1) + self.logA.T    
                P = normalize_exp(lp, axis=0)

                # Update
                V1 = np.dot(V1, P)             
                V2 = np.dot(V2, P) + I_S1S*P.reshape((1,self.S,self.S))    
                V3 = np.dot(V3, P) + I_RR[:,y[k-1]].reshape((self.R,1,1))*P.reshape((1,self.S,self.S))    

            log_alpha = self.update(y[k], log_alpha_pred)    
            p_xT = normalize_exp(log_alpha)    

        C1 = np.dot(V1, p_xT.reshape(self.S,1))
        C2 = np.dot(V2, p_xT.reshape(1,self.S,1)).reshape((self.S,self.S))
        C3 = np.dot(V3, p_xT.reshape(1,self.S,1)).reshape((self.R,self.S))
        C3[y[-1],:] +=  p_xT
        
        ll = log_sum_exp(log_alpha)
        
        return C1, C2, C3, ll, (V1, V2, V3)

    
    def train_EM(self, y, EPOCH=10, method=1):
        LL = np.zeros(EPOCH)
        for e in range(EPOCH):
            if method is 'correction_smoother':
                C1, C2, C3, log_gamma_corr = self.correction_smoother(y)
                ll = log_sum_exp(log_gamma_corr[:,0])
            elif method is 'forward_only':
                C1, C2, C3, ll, V = self.forward_only_SS(y)
            else:
                return
            LL[e] = ll
            p = normalize(C1 + 0.1, axis=0).reshape(self.S)
            # print(p,np.size(p))            
            A = normalize(C2, axis=0)
            # print(A)
            B = normalize(C3, axis=0)
            # print(B)
            self.__init__(p, A, B)
            
        return LL
    
    def online_em(self, y, V=None, n_min=100, gamma=0.2, gamma_const=0.999):
        T = len(y)
        LL = np.zeros(T)
        
        if V is None:
            V1  = np.eye((self.S))
            V2  = np.zeros((self.S,self.S,self.S))
            V3  = np.zeros((self.R,self.S,self.S))
        else:
            V1, V2, V3 = V
            
        I_S1S = np.eye(self.S).reshape((self.S,1,self.S))
        I_RR = np.eye(self.R)
        
        for k in range(T):
            # E step
            if k==0:
                log_alpha_pred = self.logpi
            else:
                log_alpha_pred = self.predict(log_alpha)

            if k>0:
                # Calculate p(x_{k-1}|y_{1:k-1}, x_k) 
                lp = np.log(normalize_exp(log_alpha)).reshape(self.S,1) + self.logA.T    
                P = normalize_exp(lp, axis=0)

                # Update
                V1 = np.dot(V1, P)             
                V2 = (1-gamma)*np.dot(V2, P) + gamma*I_S1S*P.reshape((1,self.S,self.S))    
                V3 = (1-gamma)*np.dot(V3, P) + gamma*I_RR[:,y[k-1]].reshape((self.R,1,1))*P.reshape((1,self.S,self.S))    

            log_alpha = self.update(y[k], log_alpha_pred)    
            p_xT = normalize_exp(log_alpha)    
        
            LL[k] = log_sum_exp(log_alpha)
            
            # M step
            if k > n_min:
                C1 = np.dot(V1, p_xT.reshape(self.S,1))
                C2 = np.dot(V2, p_xT.reshape(1,self.S,1)).reshape((self.S,self.S))
                C3 = np.dot(V3, p_xT.reshape(1,self.S,1)).reshape((self.R,self.S))
                C3[y[k],:] +=  p_xT
                
                p = normalize(C1 + 0.1, axis=0).reshape(self.S)
                A = normalize(C2, axis=0)
                B = normalize(C3, axis=0)
                self.__init__(p, A, B)
            
            if gamma > 1e-2:
                gamma *= gamma_const
    
        return LL

# %% [markdown]
# ### Test Code

# %%
# init an hmm and generate data
hmm_original = HMM.from_random_parameters()
L = 2000
y,x = hmm_original.generate_sequence(L)

# eval likelihood with the original params
LL = hmm_original.train_EM(y, EPOCH=50, method='correction_smoother')
print "original lhood:",LL[-1]
# plt.plot(LL)
# plt.show()

# init three random HMM's with the sama parameters
hmm1 = HMM.from_random_parameters()
hmm2 = hmm1.copy()
hmm3 = hmm1.copy()

# train the first one with correction smoother
LL1 = hmm1.train_EM(y, EPOCH=50, method='correction_smoother')
print "correction_smoother lhood:",LL1[-1]
# plt.plot(LL1)
# plt.show()

# train the second one with forward only SS
LL2 = hmm2.train_EM(y, EPOCH=50, method='forward_only')
print "forward_only_ss lhood:",LL2[-1]
# plt.plot(LL2)
# plt.show()
# print "hmm2:",hmm2,"\n"

# train the second one with forward only SS
LL3 = hmm3.online_em(y)
print "online_em lhood:",LL3[-1]
# plt.plot(LL3)
# plt.show()


hmm_random = HMM.from_random_parameters()
log_gamma = hmm_random.forward_backward_smoother(y)
print "random lhood:",log_sum_exp(log_gamma[:,0])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:60: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:59: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:48: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# original lhood: -2481.56037055
# correction_smoother lhood:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:119: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:126: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:160: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#  -2486.34803705
# forward_only_ss lhood:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:168: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:225: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#  -2486.34803705
# online_em lhood: -3083.44347107
# random lhood: [-4485.80814265]
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:237: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# ### Test Code - 2

# %%
hmm = HMM.from_random_parameters()

L = 300

y,x = hmm.generate_sequence(L)

print("Results with the Forward Smoother")
C1, C2, C3, ll, V = hmm.forward_only_SS(y)
    
print(C1)
print(np.sum(C1))

print(C2)
print(np.sum(C2))

print(C3)
print(np.sum(C3))

print("Results with the Correction Smoother")
C1_corr, C2_corr, C3_corr, lg = hmm.correction_smoother(y)

print(C1_corr)
print(np.sum(C1_corr))

print(C2_corr)
print(np.sum(C2_corr))

print(C3_corr)
print(np.sum(C3_corr))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:60: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:59: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:48: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:160: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:168: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:119: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
# Results with the Forward Smoother
# [[ 0.05573194]
#  [ 0.8084704 ]
#  [ 0.13579765]]
# 1.0
# [[ 17.58366862  85.25152472   0.10916491]
#  [ 79.15180557  98.34457285   6.382239  ]
#  [  5.6448134    0.71215981   5.82005112]]
# 299.0
# [[  1.58730202e+01   1.20818466e+01   4.51331970e-02]
#  [  8.10538283e+01   4.47315519e+01   2.14619798e-01]
#  [  8.59541317e-01   9.70798224e+00   2.43247645e+00]
#  [  4.51997743e+00   7.22990169e+01   2.18100570e+00]
#  [  6.93722925e-01   4.58666902e+01   7.43958684e+00]]
# 300.0
# Results with the Correction Smoother
# [ 0.05573194  0.8084704   0.13579765]
# 1.0
# [[ 17.58366862  85.25152472   0.10916491]
#  [ 79.15180557  98.34457285   6.382239  ]
#  [  5.6448134    0.71215981   5.82005112]]
# 299.0
# [[  1.58730202e+01   1.20818466e+01   4.51331970e-02]
#  [  8.10538283e+01   4.47315519e+01   2.14619798e-01]
#  [  8.59541317e-01   9.70798224e+00   2.43247645e+00]
#  [  4.51997743e+00   7.22990169e+01   2.18100570e+00]
#  [  6.93722925e-01   4.58666902e+01   7.43958684e+00]]
# 300.0
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:126: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %% [markdown]
# # Data Sets

# %% [markdown]
# ### Counting letter bigrams in several languages

# %%
# %matplotlib inline
from collections import defaultdict
import urllib2
import string
import numpy as np
import matplotlib.pyplot as plt
from string import maketrans   # Required to call maketrans function.

# Turkish
#"ç","ı","ğ","ö","ş","ü",'â'
# German
#"ä","ß","ö","ü"
# French
#"ù","û","ô","â","à","ç","é","è","ê","ë","î","ï","æ"
tr_alphabet = ['*','a','b','c','ç','d','e','f',
                'g','ğ','h','ı','i','j','k','l',
                'm','n','o','ö','p','q','r','s','ş',
                't','u','ü','w','v','x','y','z']
# Union of Frequent letters in French, Turkish, German and English
my_alphabet = ['*','a','â','ä',"à","æ",'b','c','ç','d','e',"é","è","ê","ë",'f',
                'g','ğ','h','ı','i',"î",'ï','j','k','l',
                'm','n','o','œ',"ô",'ö','p','q','r','s','ş',
                't','u','ù',"û",'ü','w','v','x','y','z','ß']
# Only ascii characters
ascii_alphabet = list('*'+string.ascii_lowercase)
# Reduction table from my alphabet to ascii
my2ascii_table = {
    ord(u"â"):u"a",
    ord(u"ä"):u"ae",
    ord(u"à"):u"a",
    ord(u"æ"):u"ae",
    ord(u"À"):u"a",
    ord(u"Æ"):u"a",
    ord(u"ç"):u"c",
    ord(u"Ç"):u"c",
    ord(u"é"):u"e",
    ord(u"è"):u"e",
    ord(u"ê"):u"e",
    ord(u"ë"):u"e",
    ord(u"È"):u"e",
    ord(u"Ê"):u"e",
    ord(u"É"):u"e",
    ord(u"Ë"):u"e",
    ord(u'ğ'):u"g",
    ord(u'ı'):u"i",
    ord(u"î"):u"i",
    ord(u"İ"):u"i",
    ord(u'ï'):u"i",
    ord(u'œ'):u"oe",
    ord(u"Ô"):u"o",
    ord(u"ô"):u"o",
    ord(u'Ö'):u"o",
    ord(u'ö'):u"o",
    ord(u'ş'):u"s",
    ord(u'Ş'):u"s",
    ord(u'ù'):u"u",
    ord(u"û"):u"u",
    ord(u'ü'):u"u",
    ord(u'Ü'):u"u",
    ord(u'ß'):u"ss"
    }
# Reduction table from my alphabet to frequent letters in turkish text
my2tr_table = {
    ord(u'â'):u"a",
    ord(u'ä'):u"ae",
    ord(u"à"):u"a",
    ord(u"æ"):u"ae",
    ord(u"é"):u"e",
    ord(u"è"):u"e",
    ord(u"ê"):u"e",
    ord(u"ë"):u"e",
    ord(u"î"):u"i",
    ord(u'ï'):u"i",
    ord(u'œ'):u"oe",
    ord(u"ô"):u"o",
    ord(u'ù'):u"u",
    ord(u"û"):u"u",
    ord(u'ß'):u"ss"
    }


def count_transitions(fpp, alphabet, tab):

    #ignore punctuation
    rep_chars = '.\t\n\rİ»«…’°” '
    tbrep = dict((ord(char), u"*") for char in rep_chars)
    
    delete_chars = '0123456789!"\'#$%&\(\),-/:;<=>?@[\\]^_`{|}~+'
    tbdel = dict((ord(char), None) for char in delete_chars)
    
    #replace other unicode characters with a star

    # Character pairs 
    D = defaultdict(int)

    for line in fpp:
        # s = line.decode('utf-8').translate(tb).lower()
        s = line.lower().decode('utf-8', 'ignore')
        s = s.translate(tbdel)
        s = s.translate(tbrep)
        s = s.translate(tab)

        if len(s)>1:
            for i in range(len(s)-1):
                D[s[i:i+2]]+=1
    
    M = len(alphabet)
    a2i = {v: k for k,v in enumerate(alphabet)}
    DD = np.zeros((M,M))
    
    miss = 0
    ky = sorted(D.keys())
    for k in D.keys():
        try:
            i = a2i[k[0]]
            j = a2i[k[1]]
            DD[i,j] = D[k]
        except:
            miss += 1
            print k[0], k[1]
    print "miss is %d" % miss

    return D, DD, alphabet

# %% [markdown]
# ### Count and display occurences of letters in text

# %%
local = 'data/'
#local = 'https://dl.dropboxusercontent.com/u/9787379/swe546/data/'
#files = ['starwars_4.txt', 'starwars_5.txt', 'starwars_6.txt', 'hamlet.txt','hamlet_deutsch.txt', 'hamlet_french.txt', 'juliuscaesar.txt','othello.txt', 'sonnets.txt', 'antoniusandcleopatra.txt']
files = ['hamlet_turkce.txt','hamlet_deutsch.txt', 'hamlet_french.txt', 'hamlet.txt','starwars_4.txt', 'starwars_5.txt','juliuscaesar.txt','othello.txt']

plt.figure(figsize=(16,18))

i = 0
for f in files:
    path = local+f
    # data = urlopen(url) 
    # data = urllib2.urlopen(url).read()
    data = open(path,"rb")
    #D, DD, alphabet = count_transitions(data, my_alphabet, {})
    D, DD, alphabet = count_transitions(data, ascii_alphabet, my2ascii_table)
    #D, DD, alphabet = count_transitions(data, tr_alphabet, my2tr_table)
    M = len(alphabet)
    # Ignore space, space transitions
    DD[0,0] = 1
    
    i+=1
    plt.subplot(len(files)/2,2,i)
        
    S = np.sum(DD,axis=0)
    #Subpress spaces
    S[0] = 0
    S = S/np.sum(S)

    plt.bar(np.arange(M)-0.5, S, width=0.7)
    plt.xticks(range(M), alphabet)
    plt.gca().set_ylim((0,0.2))
    plt.title(f)

plt.show()
# Out:
# t ’
# ’ m
# g ’
# ’ a
# t …
# … s
# … d
# z …
# … *
# … ”
# ’ i
# ’ l
# ’ n
# ’ e
# ’ d
# ’ y
# ’ u
# ’ t
# s ’
# y …
# l ’
# l …
# r ”
# e …
# r …
# e ’
# k …
# * “
# d ’
# ” *
# “ p
# “ b
# c ’
# i …
# i ’
# o ’
# u …
# a …
# n …
# a ’
# miss is 40
# ﻿ p
# miss is 1
# ﻿ t
# miss is 1
# miss is 0
# miss is 0
# miss is 0
# miss is 0
# miss is 0

# %% [markdown]
# ### Counting Bigrams

# %%
local = 'data/'
#local = 'https://dl.dropboxusercontent.com/u/9787379/swe546/data/'

#files = ['starwars_4.txt', 'starwars_5.txt', 'starwars_6.txt', 'hamlet.txt', 'hamlet_deutsch.txt', 'hamlet_french.txt', 'juliuscaesar.txt','othello.txt', 'sonnets.txt', 'antoniusandcleopatra.txt']
files = ['hamlet_turkce.txt','hamlet_deutsch.txt', 'hamlet_french.txt', 'hamlet.txt','starwars_4.txt', 'starwars_5.txt','juliuscaesar.txt','othello.txt']

plt.figure(figsize=(17,2*17))

i = 0
for f in files: 
    path = local+f
    data = open(path,"rb")
    #D, DD, alphabet = count_transitions(data, my_alphabet, {})
    #D, DD, alphabet = count_transitions(data, ascii_alphabet, my2ascii_table)
    D, DD, alphabet = count_transitions(data, tr_alphabet, my2tr_table)
    M = len(alphabet)
    DD[0,0] = 1
    
    i+=1
    plt.subplot(len(files)/2,2,i)
    plt.imshow(DD, interpolation='nearest', vmin=0)
    plt.xticks(range(M), alphabet)
    plt.xlabel('x(t)')
    plt.yticks(range(M), alphabet)
    plt.ylabel('x(t-1)')
    ax = plt.gca()
    ax.xaxis.tick_top()
    #ax.set_title(f, va='bottom')
    plt.xlabel('x(t) '+f)
# Out:
# 1 (Sahne yavaşçaİ aydınlanır. Hamlet arkası dönük olarak geride tabutun başında durmaktadır. Karanlığın içinden çıkan topluluk içinde Hamlet kaybolur. Kraliçe Gertrude belirir, tabuta çiçek koyar. Kraliçe geri çekilirken Claudius belirir ve Gertrude’u teselli eder. Topluluk müzik eşliğinde tabutu alır ve cenaze alayı oluşur. Yürümeye başlar. Sağ köşe aydınlanır.)
#
# 1 (sahne yavaşçaİ aydınlanır. hamlet arkası dönük olarak geride tabutun başında durmaktadır. karanlığın içinden çıkan topluluk içinde hamlet kaybolur. kraliçe gertrude belirir, tabuta çiçek koyar. kraliçe geri çekilirken claudius belirir ve gertrude’u teselli eder. topluluk müzik eşliğinde tabutu alır ve cenaze alayı oluşur. yürümeye başlar. sağ köşe aydınlanır.)
#
#  sahne yavaşçaİ aydınlanır. hamlet arkası dönük olarak geride tabutun başında durmaktadır. karanlığın içinden çıkan topluluk içinde hamlet kaybolur. kraliçe gertrude belirir tabuta çiçek koyar. kraliçe geri çekilirken claudius belirir ve gertrude’u teselli eder. topluluk müzik eşliğinde tabutu alır ve cenaze alayı oluşur. yürümeye başlar. sağ köşe aydınlanır.
#
# *sahne*yavaşçaİ*aydınlanır**hamlet*arkası*dönük*olarak*geride*tabutun*başında*durmaktadır**karanlığın*içinden*çıkan*topluluk*içinde*hamlet*kaybolur**kraliçe*gertrude*belirir*tabuta*çiçek*koyar**kraliçe*geri*çekilirken*claudius*belirir*ve*gertrude’u*teselli*eder**topluluk*müzik*eşliğinde*tabutu*alır*ve*cenaze*alayı*oluşur**yürümeye*başlar**sağ*köşe*aydınlanır**
#
#
#
#
#
#
# *
# Hamlet: Horatio, sevgili dostum. Hangi rüzgar attı seni buraya?
#
# hamlet: horatio, sevgili dostum. hangi rüzgar attı seni buraya?
#
# hamlet horatio sevgili dostum. hangi rüzgar attı seni buraya
#
# hamlet*horatio*sevgili*dostum**hangi*rüzgar*attı*seni*buraya*
#
#
#
#
#
#
# *
# Horatio: Babanızın cenazesine gelmiştim, efendimiz.
#
# horatio: babanızın cenazesine gelmiştim, efendimiz.
#
# horatio babanızın cenazesine gelmiştim efendimiz.
#
# horatio*babanızın*cenazesine*gelmiştim*efendimiz**
#
#
#
#
#
#
# *
# Hamlet: Alay etme benimle
#
# hamlet: alay etme benimle
#
# hamlet alay etme benimle
#
# hamlet*alay*etme*benimle*
#
#
#
#
#
#
# *
# Annemin düğününe gelmişsindir.
#
# annemin düğününe gelmişsindir.
#
# annemin düğününe gelmişsindir.
#
# annemin*düğününe*gelmişsindir**
#
#
#
#
#
#
# *
# Horatio: Doğrusu, biraz çabuk oldu bu düğün
#
# horatio: doğrusu, biraz çabuk oldu bu düğün
#
# horatio doğrusu biraz çabuk oldu bu düğün
#
# horatio*doğrusu*biraz*çabuk*oldu*bu*düğün*
#
#
#
#
#
#
# *
# Hamlet: Ekonomi, Horatio, ekonomi!
#
# hamlet: ekonomi, horatio, ekonomi!
#
# hamlet ekonomi horatio ekonomi
#
# hamlet*ekonomi*horatio*ekonomi*
#
#
#
#
#
#
# *
# Cenaze sofrasında sıcak yenen yemekler
#
# cenaze sofrasında sıcak yenen yemekler
#
# cenaze sofrasında sıcak yenen yemekler
#
# cenaze*sofrasında*sıcak*yenen*yemekler*
#
#
#
#
#
#
# *
# Düğün sofrasında soğuk verildi.
#
# düğün sofrasında soğuk verildi.
#
# düğün sofrasında soğuk verildi.
#
# düğün*sofrasında*soğuk*verildi**
#
#
#
#
#
#
# *
# (Köşe kararır. Cenaze alayı yoluna devam eder ve çıkar.) Sahnede kalanlar daire oluşturur. Bir tür cenaze-düğün dansına geçer. Köşe aydınlanır.)
#
# (köşe kararır. cenaze alayı yoluna devam eder ve çıkar.) sahnede kalanlar daire oluşturur. bir tür cenaze-düğün dansına geçer. köşe aydınlanır.)
#
# köşe kararır. cenaze alayı yoluna devam eder ve çıkar. sahnede kalanlar daire oluşturur. bir tür cenazedüğün dansına geçer. köşe aydınlanır.
#
# köşe*kararır**cenaze*alayı*yoluna*devam*eder*ve*çıkar**sahnede*kalanlar*daire*oluşturur**bir*tür*cenazedüğün*dansına*geçer**köşe*aydınlanır**
#
#
#
#
#
#
# *
# Hamlet: Çığrından çıkmış bir zaman bu…
#
# hamlet: Çığrından çıkmış bir zaman bu…
#
# hamlet Çığrından çıkmış bir zaman bu…
#
# hamlet*Çığrından*çıkmış*bir*zaman*bu…*
#
#
#
#
#
#
# *
# (Köşe kararır. Anlatıcılar Hamlet ile ilgili olgusal bilgileri seyirciye aktarırlar.)
#
# (köşe kararır. anlatıcılar hamlet ile ilgili olgusal bilgileri seyirciye aktarırlar.)
#
# köşe kararır. anlatıcılar hamlet ile ilgili olgusal bilgileri seyirciye aktarırlar.
#
# köşe*kararır**anlatıcılar*hamlet*ile*ilgili*olgusal*bilgileri*seyirciye*aktarırlar**
#
#
#
#
#
#
# *
# 1. Anlatıcı: Shakespeare’in en bilinen yapıtı Hamlet muhtemelen 1601 yılında yazıldı. Muhtemelen, çünkü Shakespeare’in birçok oyununun yazılış tarihi kesin olarak bilinmiyor. Oyunun ilk baskısı 1603 yılında yapılmış. Bu baskının, aktörlerin akıllarında kalan bölümlerden oluşturulduğu söyleniyor. Bundan bir iki yıl sonra Hamlet’in yeni baskısı yapılıyor. Bu kez Shakespeare’in el yazmaları esas alınıyor. Bazı araştırmacılara göre Shakespeare ilk metinde tepki çeken bölümleri bu baskıda budamış.
#
# 1. anlatıcı: shakespeare’in en bilinen yapıtı hamlet muhtemelen 1601 yılında yazıldı. muhtemelen, çünkü shakespeare’in birçok oyununun yazılış tarihi kesin olarak bilinmiyor. oyunun ilk baskısı 1603 yılında yapılmış. bu baskının, aktörlerin akıllarında kalan bölümlerden oluşturulduğu söyleniyor. bundan bir iki yıl sonra hamlet’in yeni baskısı yapılıyor. bu kez shakespeare’in el yazmaları esas alınıyor. bazı araştırmacılara göre shakespeare ilk metinde tepki çeken bölümleri bu baskıda budamış.
#
# . anlatıcı shakespeare’in en bilinen yapıtı hamlet muhtemelen  yılında yazıldı. muhtemelen çünkü shakespeare’in birçok oyununun yazılış tarihi kesin olarak bilinmiyor. oyunun ilk baskısı  yılında yapılmış. bu baskının aktörlerin akıllarında kalan bölümlerden oluşturulduğu söyleniyor. bundan bir iki yıl sonra hamlet’in yeni baskısı yapılıyor. bu kez shakespeare’in el yazmaları esas alınıyor. bazı araştırmacılara göre shakespeare ilk metinde tepki çeken bölümleri bu baskıda budamış.
#
# **anlatıcı*shakespeare’in*en*bilinen*yapıtı*hamlet*muhtemelen**yılında*yazıldı**muhtemelen*çünkü*shakespeare’in*birçok*oyununun*yazılış*tarihi*kesin*olarak*bilinmiyor**oyunun*ilk*baskısı**yılında*yapılmış**bu*baskının*aktörlerin*akıllarında*kalan*bölümlerden*oluşturulduğu*söyleniyor**bundan*bir*iki*yıl*sonra*hamlet’in*yeni*baskısı*yapılıyor**bu*kez*shakespeare’in*el*yazmaları*esas*alınıyor**bazı*araştırmacılara*göre*shakespeare*ilk*metinde*tepki*çeken*bölümleri*bu*baskıda*budamış**
#
#
#
#
#
#
# *
# 2. Anlatıcı: O donemde İngiltere’de oyun yazarları halk arasında iyi bilinen temaları alır ve onları en özgün şekilde anlatmaya çalışırlardı. Shakespeare’de kendi oyununu kurgularken Thomas Kyd’in İspanyol Trajedisi adlı oyunundan ve Belleforest’in yazdığı intikam temalı bir masaldan yararlandı. Tarihsel ayrıntılar içinse Saxo Grammaticus tarafından yazılan Danimarka Tarihi’nden yardım aldı. Ancak Shakespeare’in Hamlet’inin ünü kendi döneminde de, daha sonra da bütün bu eserlerin ötesine geçti. Ayni donemde bazı eleştirmenler `halk tiyatroları`nı daha fazla seyirci çekmekten başka amacı olmayan derinliksiz ürünler vermekle suçluyorlardı. Hamlet bu eleştirilere iyi bir yanıt oldu ve Shakespeare tiyatrosunun bir halk tiyatrosu olarak ne kadar yüksek bir düzeye ulaştığını gösterdi.
#
# 2. anlatıcı: o donemde İngiltere’de oyun yazarları halk arasında iyi bilinen temaları alır ve onları en özgün şekilde anlatmaya çalışırlardı. shakespeare’de kendi oyununu kurgularken thomas kyd’in İspanyol trajedisi adlı oyunundan ve belleforest’in yazdığı intikam temalı bir masaldan yararlandı. tarihsel ayrıntılar içinse saxo grammaticus tarafından yazılan danimarka tarihi’nden yardım aldı. ancak shakespeare’in hamlet’inin ünü kendi döneminde de, daha sonra da bütün bu eserlerin ötesine geçti. ayni donemde bazı eleştirmenler `halk tiyatroları`nı daha fazla seyirci çekmekten başka amacı olmayan derinliksiz ürünler vermekle suçluyorlardı. hamlet bu eleştirilere iyi bir yanıt oldu ve shakespeare tiyatrosunun bir halk tiyatrosu olarak ne kadar yüksek bir düzeye ulaştığını gösterdi.
#
# . anlatıcı o donemde İngiltere’de oyun yazarları halk arasında iyi bilinen temaları alır ve onları en özgün şekilde anlatmaya çalışırlardı. shakespeare’de kendi oyununu kurgularken thomas kyd’in İspanyol trajedisi adlı oyunundan ve belleforest’in yazdığı intikam temalı bir masaldan yararlandı. tarihsel ayrıntılar içinse saxo grammaticus tarafından yazılan danimarka tarihi’nden yardım aldı. ancak shakespeare’in hamlet’inin ünü kendi döneminde de daha sonra da bütün bu eserlerin ötesine geçti. ayni donemde bazı eleştirmenler halk tiyatrolarını daha fazla seyirci çekmekten başka amacı olmayan derinliksiz ürünler vermekle suçluyorlardı. hamlet bu eleştirilere iyi bir yanıt oldu ve shakespeare tiyatrosunun bir halk tiyatrosu olarak ne kadar yüksek bir düzeye ulaştığını gösterdi.
#
# **anlatıcı*o*donemde*İngiltere’de*oyun*yazarları*halk*arasında*iyi*bilinen*temaları*alır*ve*onları*en*özgün*şekilde*anlatmaya*çalışırlardı**shakespeare’de*kendi*oyununu*kurgularken*thomas*kyd’in*İspanyol*trajedisi*adlı*oyunundan*ve*belleforest’in*yazdığı*intikam*temalı*bir*masaldan*yararlandı**tarihsel*ayrıntılar*içinse*saxo*grammaticus*tarafından*yazılan*danimarka*tarihi’nden*yardım*aldı**ancak*shakespeare’in*hamlet’inin*ünü*kendi*döneminde*de*daha*sonra*da*bütün*bu*eserlerin*ötesine*geçti**ayni*donemde*bazı*eleştirmenler*halk*tiyatrolarını*daha*fazla*seyirci*çekmekten*başka*amacı*olmayan*derinliksiz*ürünler*vermekle*suçluyorlardı**hamlet*bu*eleştirilere*iyi*bir*yanıt*oldu*ve*shakespeare*tiyatrosunun*bir*halk*tiyatrosu*olarak*ne*kadar*yüksek*bir*düzeye*ulaştığını*gösterdi**
#
#
#
#
#
#
# *
# 1. Anlatıcı: Shakespeare’in yaşadığı dönem oldukça kaotik bir dönemdi. Eski bir düzen yıkılıyor, yeni bir dünya sistemi ortaya çıkıyordu. Her alanda belirsizlik ve karmaşa hakimdi. Bu büyük toplumsal dönüşümün Shakespeare’in bütün oyunlarına damgasını vurduğunu söyleyebiliriz. Birazdan birinci perdesini izleyeceğiniz Hamlet’te de bu dönüşümün izlerini görmek mümkün.
#
# 1. anlatıcı: shakespeare’in yaşadığı dönem oldukça kaotik bir dönemdi. eski bir düzen yıkılıyor, yeni bir dünya sistemi ortaya çıkıyordu. her alanda belirsizlik ve karmaşa hakimdi. bu büyük toplumsal dönüşümün shakespeare’in bütün oyunlarına damgasını vurduğunu söyleyebiliriz. birazdan birinci perdesini izleyeceğiniz hamlet’te de bu dönüşümün izlerini görmek mümkün.
#
# . anlatıcı shakespeare’in yaşadığı dönem oldukça kaotik bir dönemdi. eski bir düzen yıkılıyor yeni bir dünya sistemi ortaya çıkıyordu. her alanda belirsizlik ve karmaşa hakimdi. bu büyük toplumsal dönüşümün shakespeare’in bütün oyunlarına damgasını vurduğunu söyleyebiliriz. birazdan birinci perdesini izleyeceğiniz hamlet’te de bu dönüşümün izlerini görmek mümkün.
#
# **anlatıcı*shakespeare’in*yaşadığı*dönem*oldukça*kaotik*bir*dönemdi**eski*bir*düzen*yıkılıyor*yeni*bir*dünya*sistemi*ortaya*çıkıyordu**her*alanda*belirsizlik*ve*karmaşa*hakimdi**bu*büyük*toplumsal*dönüşümün*shakespeare’in*bütün*oyunlarına*damgasını*vurduğunu*söyleyebiliriz**birazdan*birinci*perdesini*izleyeceğiniz*hamlet’te*de*bu*dönüşümün*izlerini*görmek*mümkün**
#
#
#
#
#
#
# *
# 2. Anlatıcı: Shakespeare’in başarısının sırrı toplumun çok farklı kesimlerinden insanlara hitap edebilmesinde yatıyordu. Shakespeare’in tiyatro binası Globe’u incelememiz bunu daha iyi anlamamıza yardımcı olabilir. Sahnenin hemen önünde büyük bir alan vardı. Üzeri açık olan bu alan ayaktakımına ayrılmıştı. Parası kapalı parterde oturmaya yetmeyen bütün yoksullar oyunu buradan seyrederdi. Gürültücü ve hareketli bir kitleydi bu. Üç katlı kapalı parterin ilk iki katında oturanlar cebi bir parça para görmüş burjuvalardan bazı din adamlarına varan geniş bir yelpaze oluşturuyordu. Üçüncü kattaki localar oynanan oyunla pek ilgilenmeyenler için ayrılmıştı. Aşağıda anlasan fahişe ve müşterisi burada işi pişirir, bazı gizli toplantılar burada yapılırdı. Soylulara ya da soyluluğa özenen büyük burjuvalara gelince… Onlar sahnenin gerisindeki lüks balkonda otururlardı; çünkü onlar için önemli olan oyunu seyretmek değil, oyunu dinlemek ve diğer seyirciler tarafından seyredilmekti. İşte Shakespeare’in yüksek düzeyli halk tiyatrosu böyle bir ortamda doğdu.
#
# 2. anlatıcı: shakespeare’in başarısının sırrı toplumun çok farklı kesimlerinden insanlara hitap edebilmesinde yatıyordu. shakespeare’in tiyatro binası globe’u incelememiz bunu daha iyi anlamamıza yardımcı olabilir. sahnenin hemen önünde büyük bir alan vardı. Üzeri açık olan bu alan ayaktakımına ayrılmıştı. parası kapalı parterde oturmaya yetmeyen bütün yoksullar oyunu buradan seyrederdi. gürültücü ve hareketli bir kitleydi bu. Üç katlı kapalı parterin ilk iki katında oturanlar cebi bir parça para görmüş burjuvalardan bazı din adamlarına varan geniş bir yelpaze oluşturuyordu. Üçüncü kattaki localar oynanan oyunla pek ilgilenmeyenler için ayrılmıştı. aşağıda anlasan fahişe ve müşterisi burada işi pişirir, bazı gizli toplantılar burada yapılırdı. soylulara ya da soyluluğa özenen büyük burjuvalara gelince… onlar sahnenin gerisindeki lüks balkonda otururlardı; çünkü onlar için önemli olan oyunu seyretmek değil, oyunu dinlemek ve diğer seyirciler tarafından seyredilmekti. İşte shakespeare’in yüksek düzeyli halk tiyatrosu böyle bir ortamda doğdu.
#
# . anlatıcı shakespeare’in başarısının sırrı toplumun çok farklı kesimlerinden insanlara hitap edebilmesinde yatıyordu. shakespeare’in tiyatro binası globe’u incelememiz bunu daha iyi anlamamıza yardımcı olabilir. sahnenin hemen önünde büyük bir alan vardı. Üzeri açık olan bu alan ayaktakımına ayrılmıştı. parası kapalı parterde oturmaya yetmeyen bütün yoksullar oyunu buradan seyrederdi. gürültücü ve hareketli bir kitleydi bu. Üç katlı kapalı parterin ilk iki katında oturanlar cebi bir parça para görmüş burjuvalardan bazı din adamlarına varan geniş bir yelpaze oluşturuyordu. Üçüncü kattaki localar oynanan oyunla pek ilgilenmeyenler için ayrılmıştı. aşağıda anlasan fahişe ve müşterisi burada işi pişirir bazı gizli toplantılar burada yapılırdı. soylulara ya da soyluluğa özenen büyük burjuvalara gelince… onlar sahnenin gerisindeki lüks balkonda otururlardı çünkü onlar için önemli olan oyunu seyretmek değil oyunu dinlemek ve diğer seyirciler tarafından seyredilmekti. İşte shakespeare’in yüksek düzeyli halk tiyatrosu böyle bir ortamda doğdu.
#
# **anlatıcı*shakespeare’in*başarısının*sırrı*toplumun*çok*farklı*kesimlerinden*insanlara*hitap*edebilmesinde*yatıyordu**shakespeare’in*tiyatro*binası*globe’u*incelememiz*bunu*daha*iyi*anlamamıza*yardımcı*olabilir**sahnenin*hemen*önünde*büyük*bir*alan*vardı**Üzeri*açık*olan*bu*alan*ayaktakımına*ayrılmıştı**parası*kapalı*parterde*oturmaya*yetmeyen*bütün*yoksullar*oyunu*buradan*seyrederdi**gürültücü*ve*hareketli*bir*kitleydi*bu**Üç*katlı*kapalı*parterin*ilk*iki*katında*oturanlar*cebi*bir*parça*para*görmüş*burjuvalardan*bazı*din*adamlarına*varan*geniş*bir*yelpaze*oluşturuyordu**Üçüncü*kattaki*localar*oynanan*oyunla*pek*ilgilenmeyenler*için*ayrılmıştı**aşağıda*anlasan*fahişe*ve*müşterisi*burada*işi*pişirir*bazı*gizli*toplantılar*burada*yapılırdı**soylulara*ya*da*soyluluğa*özenen*büyük*burjuvalara*gelince…*onlar*sahnenin*gerisindeki*lüks*balkonda*otururlardı*çünkü*onlar*için*önemli*olan*oyunu*seyretmek*değil*oyunu*dinlemek*ve*diğer*seyirciler*tarafından*seyredilmekti**İşte*shakespeare’in*yüksek*düzeyli*halk*tiyatrosu*böyle*bir*ortamda*doğdu**
#
#
#
#
#
#
# *
# 1. Anlatıcı: Danimarka Prensi Hamlet’in Trajedisi. Yazan William Shakespeare. Birinci perde. Birinci sahne. Elsinore Şatosu surları. Nöbet tutan askerler. (Sahnenin önündeki koridorda loş bir ışık yanar. Askerler karşılıklı olarak geçerler.) Soğuk, karanlık, uğursuz bir gece. Sanki atmosfer, ülkenin içinde bulunduğu duruma bir ayna tutmaktadır: tedirgin bir bekleyiş. (Öndeki askerler bir geçişi tamamlamışlardır. Işıkları kararır.) O gece nöbet tutmakta olan Marcellus ve Barnardo Hamlet’in dostu Horatio’yu da nöbet yerine çağırmışlardır. Ona göstermek istedikleri bir şey vardır. Onlara göre ülkedeki kötü gidişatı, yozlaşmayı simgeleyen uğursuz bir şeydir bu.
#
# 1. anlatıcı: danimarka prensi hamlet’in trajedisi. yazan william shakespeare. birinci perde. birinci sahne. elsinore Şatosu surları. nöbet tutan askerler. (sahnenin önündeki koridorda loş bir ışık yanar. askerler karşılıklı olarak geçerler.) soğuk, karanlık, uğursuz bir gece. sanki atmosfer, ülkenin içinde bulunduğu duruma bir ayna tutmaktadır: tedirgin bir bekleyiş. (Öndeki askerler bir geçişi tamamlamışlardır. işıkları kararır.) o gece nöbet tutmakta olan marcellus ve barnardo hamlet’in dostu horatio’yu da nöbet yerine çağırmışlardır. ona göstermek istedikleri bir şey vardır. onlara göre ülkedeki kötü gidişatı, yozlaşmayı simgeleyen uğursuz bir şeydir bu.
#
# . anlatıcı danimarka prensi hamlet’in trajedisi. yazan william shakespeare. birinci perde. birinci sahne. elsinore Şatosu surları. nöbet tutan askerler. sahnenin önündeki koridorda loş bir ışık yanar. askerler karşılıklı olarak geçerler. soğuk karanlık uğursuz bir gece. sanki atmosfer ülkenin içinde bulunduğu duruma bir ayna tutmaktadır tedirgin bir bekleyiş. Öndeki askerler bir geçişi tamamlamışlardır. işıkları kararır. o gece nöbet tutmakta olan marcellus ve barnardo hamlet’in dostu horatio’yu da nöbet yerine çağırmışlardır. ona göstermek istedikleri bir şey vardır. onlara göre ülkedeki kötü gidişatı yozlaşmayı simgeleyen uğursuz bir şeydir bu.
#
# **anlatıcı*danimarka*prensi*hamlet’in*trajedisi**yazan*william*shakespeare**birinci*perde**birinci*sahne**elsinore*Şatosu*surları**nöbet*tutan*askerler**sahnenin*önündeki*koridorda*loş*bir*ışık*yanar**askerler*karşılıklı*olarak*geçerler**soğuk*karanlık*uğursuz*bir*gece**sanki*atmosfer*ülkenin*içinde*bulunduğu*duruma*bir*ayna*tutmaktadır*tedirgin*bir*bekleyiş**Öndeki*askerler*bir*geçişi*tamamlamışlardır**işıkları*kararır**o*gece*nöbet*tutmakta*olan*marcellus*ve*barnardo*hamlet’in*dostu*horatio’yu*da*nöbet*yerine*çağırmışlardır**ona*göstermek*istedikleri*bir*şey*vardır**onlara*göre*ülkedeki*kötü*gidişatı*yozlaşmayı*simgeleyen*uğursuz*bir*şeydir*bu**
#
#
#
#
#
#
# *
# (Ani bir ışık değişimi ve gerilimli bir müzik girer. Marcellus, Barnardo ve Horatio kılıçlarını çekmiş, birbirlerine yapışmıştır.)
#
# (ani bir ışık değişimi ve gerilimli bir müzik girer. marcellus, barnardo ve horatio kılıçlarını çekmiş, birbirlerine yapışmıştır.)
#
# ani bir ışık değişimi ve gerilimli bir müzik girer. marcellus barnardo ve horatio kılıçlarını çekmiş birbirlerine yapışmıştır.
#
# ani*bir*ışık*değişimi*ve*gerilimli*bir*müzik*girer**marcellus*barnardo*ve*horatio*kılıçlarını*çekmiş*birbirlerine*yapışmıştır**
#
#
#
#
#
#
# *
# Barnardo: Nasıl da ölen krala benziyor! Gördün değil mi Horatio.
#
# barnardo: nasıl da ölen krala benziyor! gördün değil mi horatio.
#
# barnardo nasıl da ölen krala benziyor gördün değil mi horatio.
#
# barnardo*nasıl*da*ölen*krala*benziyor*gördün*değil*mi*horatio**
#
#
#
#
#
#
# *
# Horatio: Gördüm. Gördüm de dondum kaldım dehşetimden.
#
# horatio: gördüm. gördüm de dondum kaldım dehşetimden.
#
# horatio gördüm. gördüm de dondum kaldım dehşetimden.
#
# horatio*gördüm**gördüm*de*dondum*kaldım*dehşetimden**
#
#
#
#
#
#
# *
# Barnardo: Konuşalım istiyor galiba!
#
# barnardo: konuşalım istiyor galiba!
#
# barnardo konuşalım istiyor galiba
#
# barnardo*konuşalım*istiyor*galiba*
#
#
#
#
#
#
# *
# Marcellus: Sen okumuş-yazmış adamsın Horatio, konuş onunla.
#
# marcellus: sen okumuş-yazmış adamsın horatio, konuş onunla.
#
# marcellus sen okumuşyazmış adamsın horatio konuş onunla.
#
# marcellus*sen*okumuşyazmış*adamsın*horatio*konuş*onunla**
#
#
#
#
#
#
# *
# Horatio: Kimsin, nesin sen? Gecenin  bu saatinde,
#
# horatio: kimsin, nesin sen? gecenin  bu saatinde,
#
# horatio kimsin nesin sen gecenin  bu saatinde
#
# horatio*kimsin*nesin*sen*gecenin**bu*saatinde*
#
#
#
#
#
#
# *
# Mezardaki haşmetli Danimarka kralının
#
# mezardaki haşmetli danimarka kralının
#
# mezardaki haşmetli danimarka kralının
#
# mezardaki*haşmetli*danimarka*kralının*
#
#
#
#
#
#
# *
# Güzelim savaş kılığına girip dolaşan?
#
# güzelim savaş kılığına girip dolaşan?
#
# güzelim savaş kılığına girip dolaşan
#
# güzelim*savaş*kılığına*girip*dolaşan*
#
#
#
#
#
#
# *
# Söyle, Tanrı aşkına, konuş diyorum sana!
#
# söyle, tanrı aşkına, konuş diyorum sana!
#
# söyle tanrı aşkına konuş diyorum sana
#
# söyle*tanrı*aşkına*konuş*diyorum*sana*
#
#
#
#
#
#
# *
# Marcellus: Kızdırdık onu!
#
# marcellus: kızdırdık onu!
#
# marcellus kızdırdık onu
#
# marcellus*kızdırdık*onu*
#
#
#
#
#
#
# *
# Barnardo: Uzaklaşıyor, bakın!
#
# barnardo: uzaklaşıyor, bakın!
#
# barnardo uzaklaşıyor bakın
#
# barnardo*uzaklaşıyor*bakın*
#
#
#
#
#
#
# *
# Horatio: Kaçma, gel buraya!
#
# horatio: kaçma, gel buraya!
#
# horatio kaçma gel buraya
#
# horatio*kaçma*gel*buraya*
#
#
#
#
#
#
# *
# (Müzik ve efektler yavaş yavaş yok  olur.)
#
# (müzik ve efektler yavaş yavaş yok  olur.)
#
# müzik ve efektler yavaş yavaş yok  olur.
#
# müzik*ve*efektler*yavaş*yavaş*yok**olur**
#
#
#
#
#
#
# *
# Marcellus: Gitti gider.
#
# marcellus: gitti gider.
#
# marcellus gitti gider.
#
# marcellus*gitti*gider**
#
#
#
#
#
#
# *
# Barnardo: Ne diyorsun bu işe Horatio?
#
# barnardo: ne diyorsun bu işe horatio?
#
# barnardo ne diyorsun bu işe horatio
#
# barnardo*ne*diyorsun*bu*işe*horatio*
#
#
#
#
#
#
# *
# Horatio: Tanrı inandırsın, iki gözüm çıksın ki
#
# horatio: tanrı inandırsın, iki gözüm çıksın ki
#
# horatio tanrı inandırsın iki gözüm çıksın ki
#
# horatio*tanrı*inandırsın*iki*gözüm*çıksın*ki*
#
#
#
#
#
#
# *
# Kendi gözlerimle görmeseydim bunu eğer,
#
# kendi gözlerimle görmeseydim bunu eğer,
#
# kendi gözlerimle görmeseydim bunu eğer
#
# kendi*gözlerimle*görmeseydim*bunu*eğer*
#
#
#
#
#
#
# *
# Dünyada inanmazdım.
#
# dünyada inanmazdım.
#
# dünyada inanmazdım.
#
# dünyada*inanmazdım**
#
#
#
#
#
#
# *
# Marcellus: Nasıl benziyor değil mi ölen krala?
#
# marcellus: nasıl benziyor değil mi ölen krala?
#
# marcellus nasıl benziyor değil mi ölen krala
#
# marcellus*nasıl*benziyor*değil*mi*ölen*krala*
#
#
#
#
#
#
# *
# Horatio: Senin sana benzediğin kadar!
#
# horatio: senin sana benzediğin kadar!
#
# horatio senin sana benzediğin kadar
#
# horatio*senin*sana*benzediğin*kadar*
#
#
#
#
#
#
# *
# Bu zırhlardı kuşandığı
#
# bu zırhlardı kuşandığı
#
# bu zırhlardı kuşandığı
#
# bu*zırhlardı*kuşandığı*
#
#
#
#
#
#
# *
# Azgın Norveç kralıyla savaştığı zaman
#
# azgın norveç kralıyla savaştığı zaman
#
# azgın norveç kralıyla savaştığı zaman
#
# azgın*norveç*kralıyla*savaştığı*zaman*
#
#
#
#
#
#
# *
# Böyle çatıktı kaşları, bir öfkeli konuşmada
#
# böyle çatıktı kaşları, bir öfkeli konuşmada
#
# böyle çatıktı kaşları bir öfkeli konuşmada
#
# böyle*çatıktı*kaşları*bir*öfkeli*konuşmada*
#
#
#
#
#
#
# *
# Baltasını çalarken taşlara
#
# baltasını çalarken taşlara
#
# baltasını çalarken taşlara
#
# baltasını*çalarken*taşlara*
#
#
#
#
#
#
# *
# Olur şey değil!…
#
# olur şey değil!…
#
# olur şey değil…
#
# olur*şey*değil…*
#
#
#
#
#
#
# *
# Barnardo: Bundan önce iki sefer, tam bu ölü saatte
#
# barnardo: bundan önce iki sefer, tam bu ölü saatte
#
# barnardo bundan önce iki sefer tam bu ölü saatte
#
# barnardo*bundan*önce*iki*sefer*tam*bu*ölü*saatte*
#
#
#
#
#
#
# *
# Nöbetteyken önümüzden geçti böyle pür azamet.
#
# nöbetteyken önümüzden geçti böyle pür azamet.
#
# nöbetteyken önümüzden geçti böyle pür azamet.
#
# nöbetteyken*önümüzden*geçti*böyle*pür*azamet**
#
#
#
#
#
#
# *
# Horatio: Nasıl yorumlamalı bunu bilemiyorum;
#
# horatio: nasıl yorumlamalı bunu bilemiyorum;
#
# horatio nasıl yorumlamalı bunu bilemiyorum
#
# horatio*nasıl*yorumlamalı*bunu*bilemiyorum*
#
#
#
#
#
#
# *
# Marcellus: Benim aklım şuna yatıyor ilk ağızda:
#
# marcellus: benim aklım şuna yatıyor ilk ağızda:
#
# marcellus benim aklım şuna yatıyor ilk ağızda
#
# marcellus*benim*aklım*şuna*yatıyor*ilk*ağızda*
#
#
#
#
#
#
# *
# Büyük belalar var gelecek, memleketin başına.
#
# büyük belalar var gelecek, memleketin başına.
#
# büyük belalar var gelecek memleketin başına.
#
# büyük*belalar*var*gelecek*memleketin*başına**
#
#
#
#
#
#
# *
# Horatio: Büyük belalar var gelecek, memleketin başına…
#
# horatio: büyük belalar var gelecek, memleketin başına…
#
# horatio büyük belalar var gelecek memleketin başına…
#
# horatio*büyük*belalar*var*gelecek*memleketin*başına…*
#
#
#
#
#
#
# *
# Düşüncenin gözünü dürten bir çöp bu
#
# düşüncenin gözünü dürten bir çöp bu
#
# düşüncenin gözünü dürten bir çöp bu
#
# düşüncenin*gözünü*dürten*bir*çöp*bu*
#
#
#
#
#
#
# *
# Roma’nın en parlak, en şanlı günlerinde,
#
# roma’nın en parlak, en şanlı günlerinde,
#
# roma’nın en parlak en şanlı günlerinde
#
# roma’nın*en*parlak*en*şanlı*günlerinde*
#
#
#
#
#
#
# *
# Koca Sezar yıkılmazdan önce,
#
# koca sezar yıkılmazdan önce,
#
# koca sezar yıkılmazdan önce
#
# koca*sezar*yıkılmazdan*önce*
#
#
#
#
#
#
# *
# Mezarlar boşalmış, Roma sokaklarında
#
# mezarlar boşalmış, roma sokaklarında
#
# mezarlar boşalmış roma sokaklarında
#
# mezarlar*boşalmış*roma*sokaklarında*
#
#
#
#
#
#
# *
# Kefenli hortlaklar kaynaşır, bağrışır olmuş.
#
# kefenli hortlaklar kaynaşır, bağrışır olmuş.
#
# kefenli hortlaklar kaynaşır bağrışır olmuş.
#
# kefenli*hortlaklar*kaynaşır*bağrışır*olmuş**
#
#
#
#
#
#
# *
# Marcellus: Nedir bu sıkı-düzen, bu kuşkulu durum memlekette?
#
# marcellus: nedir bu sıkı-düzen, bu kuşkulu durum memlekette?
#
# marcellus nedir bu sıkıdüzen bu kuşkulu durum memlekette
#
# marcellus*nedir*bu*sıkıdüzen*bu*kuşkulu*durum*memlekette*
#
#
#
#
#
#
# *
# Geceler gecesi nöbet tutturmak millete?
#
# geceler gecesi nöbet tutturmak millete?
#
# geceler gecesi nöbet tutturmak millete
#
# geceler*gecesi*nöbet*tutturmak*millete*
#
#
#
#
#
#
# *
# Neden tunç toplar dökülüyor harıl harıl?
#
# neden tunç toplar dökülüyor harıl harıl?
#
# neden tunç toplar dökülüyor harıl harıl
#
# neden*tunç*toplar*dökülüyor*harıl*harıl*
#
#
#
#
#
#
# *
# Neden bunca savaş gereçleri alıyoruz dışarıdan?
#
# neden bunca savaş gereçleri alıyoruz dışarıdan?
#
# neden bunca savaş gereçleri alıyoruz dışarıdan
#
# neden*bunca*savaş*gereçleri*alıyoruz*dışarıdan*
#
#
#
#
#
#
# *
# Neden gemi ustaları dur yok dinlen yok
#
# neden gemi ustaları dur yok dinlen yok
#
# neden gemi ustaları dur yok dinlen yok
#
# neden*gemi*ustaları*dur*yok*dinlen*yok*
#
#
#
#
#
#
# *
# Pazar yok bayram yok çalışıyorlar harıl harıl?
#
# pazar yok bayram yok çalışıyorlar harıl harıl?
#
# pazar yok bayram yok çalışıyorlar harıl harıl
#
# pazar*yok*bayram*yok*çalışıyorlar*harıl*harıl*
#
#
#
#
#
#
# *
# Ne için olabilir bu telaş bu kıyamet,
#
# ne için olabilir bu telaş bu kıyamet,
#
# ne için olabilir bu telaş bu kıyamet
#
# ne*için*olabilir*bu*telaş*bu*kıyamet*
#
#
#
#
#
#
# *
# Bu geceyi gündüze katan çalışma?
#
# bu geceyi gündüze katan çalışma?
#
# bu geceyi gündüze katan çalışma
#
# bu*geceyi*gündüze*katan*çalışma*
#
#
#
#
#
#
# *
# İçinizde bilen varsa, söylesin.
#
# İçinizde bilen varsa, söylesin.
#
# İçinizde bilen varsa söylesin.
#
# İçinizde*bilen*varsa*söylesin**
#
#
#
#
#
#
# *
# Horatio: Ben söyleyeyim. Söylentiye dayanarak tabii…
#
# horatio: ben söyleyeyim. söylentiye dayanarak tabii…
#
# horatio ben söyleyeyim. söylentiye dayanarak tabii…
#
# horatio*ben*söyleyeyim**söylentiye*dayanarak*tabii…*
#
#
#
#
#
#
# *
# Norveç Kralı Fortinbras, biliyorsunuz
#
# norveç kralı fortinbras, biliyorsunuz
#
# norveç kralı fortinbras biliyorsunuz
#
# norveç*kralı*fortinbras*biliyorsunuz*
#
#
#
#
#
#
# *
# Gururdan kıskançlıktan gözleri dönüp
#
# gururdan kıskançlıktan gözleri dönüp
#
# gururdan kıskançlıktan gözleri dönüp
#
# gururdan*kıskançlıktan*gözleri*dönüp*
#
#
#
#
#
#
# *
# Teke tek bir savaşa çağırmıştı
#
# teke tek bir savaşa çağırmıştı
#
# teke tek bir savaşa çağırmıştı
#
# teke*tek*bir*savaşa*çağırmıştı*
#
#
#
#
#
#
# *
# Demin bize görünen rahmetli kralı
#
# demin bize görünen rahmetli kralı
#
# demin bize görünen rahmetli kralı
#
# demin*bize*görünen*rahmetli*kralı*
#
#
#
#
#
#
# *
# Ve Hamlet’imiz öldürmüştü bu Fortinbras’ı.
#
# ve hamlet’imiz öldürmüştü bu fortinbras’ı.
#
# ve hamlet’imiz öldürmüştü bu fortinbras’ı.
#
# ve*hamlet’imiz*öldürmüştü*bu*fortinbras’ı**
#
#
#
#
#
#
# *
# Yapılan sözleşme gereğince de
#
# yapılan sözleşme gereğince de
#
# yapılan sözleşme gereğince de
#
# yapılan*sözleşme*gereğince*de*
#
#
#
#
#
#
# *
# Hamlet’e kalmıştı Fortinbras’ın varı yoğu.
#
# hamlet’e kalmıştı fortinbras’ın varı yoğu.
#
# hamlet’e kalmıştı fortinbras’ın varı yoğu.
#
# hamlet’e*kalmıştı*fortinbras’ın*varı*yoğu**
#
#
#
#
#
#
# *
# Gelgelelim Fortinbras’ın oğlu,
#
# gelgelelim fortinbras’ın oğlu,
#
# gelgelelim fortinbras’ın oğlu
#
# gelgelelim*fortinbras’ın*oğlu*
#
#
#
#
#
#
# *
# Pervasız, azgın bir delikanlı,
#
# pervasız, azgın bir delikanlı,
#
# pervasız azgın bir delikanlı
#
# pervasız*azgın*bir*delikanlı*
#
#
#
#
#
#
# *
# Norveç’in sınır boylarından,
#
# norveç’in sınır boylarından,
#
# norveç’in sınır boylarından
#
# norveç’in*sınır*boylarından*
#
#
#
#
#
#
# *
# Bir sürü gözü pek haydut topluyor
#
# bir sürü gözü pek haydut topluyor
#
# bir sürü gözü pek haydut topluyor
#
# bir*sürü*gözü*pek*haydut*topluyor*
#
#
#
#
#
#
# *
# Para pul ve yiyecek aşkına,
#
# para pul ve yiyecek aşkına,
#
# para pul ve yiyecek aşkına
#
# para*pul*ve*yiyecek*aşkına*
#
#
#
#
#
#
# *
# Amansız bir saldırıya hazırlıyor onları.
#
# amansız bir saldırıya hazırlıyor onları.
#
# amansız bir saldırıya hazırlıyor onları.
#
# amansız*bir*saldırıya*hazırlıyor*onları**
#
#
#
#
#
#
# *
# Babasının yitirdiği toprakları
#
# babasının yitirdiği toprakları
#
# babasının yitirdiği toprakları
#
# babasının*yitirdiği*toprakları*
#
#
#
#
#
#
# *
# Bir vurgunla almak istiyor elimizden.
#
# bir vurgunla almak istiyor elimizden.
#
# bir vurgunla almak istiyor elimizden.
#
# bir*vurgunla*almak*istiyor*elimizden**
#
#
#
#
#
#
# *
# Bence bu olacak baş nedeni
#
# bence bu olacak baş nedeni
#
# bence bu olacak baş nedeni
#
# bence*bu*olacak*baş*nedeni*
#
#
#
#
#
#
# *
# Girişilen hazırlıkların, tetikte durmaların.
#
# girişilen hazırlıkların, tetikte durmaların.
#
# girişilen hazırlıkların tetikte durmaların.
#
# girişilen*hazırlıkların*tetikte*durmaların**
#
#
#
#
#
#
# *
# Memleketi bunaltan telaşın kaynağı bu.
#
# memleketi bunaltan telaşın kaynağı bu.
#
# memleketi bunaltan telaşın kaynağı bu.
#
# memleketi*bunaltan*telaşın*kaynağı*bu**
#
#
#
#
#
#
# *
# Barnardo: Bence de başka sebep olamaz.
#
# barnardo: bence de başka sebep olamaz.
#
# barnardo bence de başka sebep olamaz.
#
# barnardo*bence*de*başka*sebep*olamaz**
#
#
#
#
#
#
# *
# İspatı da bu korkunç görüntü işte,
#
# İspatı da bu korkunç görüntü işte,
#
# İspatı da bu korkunç görüntü işte
#
# İspatı*da*bu*korkunç*görüntü*işte*
#
#
#
#
#
#
# *
# (Hayalet yeniden görünür.)
#
# (hayalet yeniden görünür.)
#
# hayalet yeniden görünür.
#
# hayalet*yeniden*görünür**
#
#
#
#
#
#
# *
# Horatio: Bakın geliyor yine.
#
# horatio: bakın geliyor yine.
#
# horatio bakın geliyor yine.
#
# horatio*bakın*geliyor*yine**
#
#
#
#
#
#
# *
# Çiğneyip geçse de gidip konuşacağım onunla
#
# Çiğneyip geçse de gidip konuşacağım onunla
#
# Çiğneyip geçse de gidip konuşacağım onunla
#
# Çiğneyip*geçse*de*gidip*konuşacağım*onunla*
#
#
#
#
#
#
# *
# Sesin varsa, kullanabiliyorsan sesini
#
# sesin varsa, kullanabiliyorsan sesini
#
# sesin varsa kullanabiliyorsan sesini
#
# sesin*varsa*kullanabiliyorsan*sesini*
#
#
#
#
#
#
# *
# Konuş benimle. Söyle!
#
# konuş benimle. söyle!
#
# konuş benimle. söyle
#
# konuş*benimle**söyle*
#
#
#
#
#
#
# *
# Gerçekten varsa bir bela
#
# gerçekten varsa bir bela
#
# gerçekten varsa bir bela
#
# gerçekten*varsa*bir*bela*
#
#
#
#
#
#
# *
# Memleketimizin başında dolaşan,
#
# memleketimizin başında dolaşan,
#
# memleketimizin başında dolaşan
#
# memleketimizin*başında*dolaşan*
#
#
#
#
#
#
# *
# Önleyebileceğimiz bir beladır belki.
#
# Önleyebileceğimiz bir beladır belki.
#
# Önleyebileceğimiz bir beladır belki.
#
# Önleyebileceğimiz*bir*beladır*belki**
#
#
#
#
#
#
# *
# (Hayalet kaybolur.)
#
# (hayalet kaybolur.)
#
# hayalet kaybolur.
#
# hayalet*kaybolur**
#
#
#
#
#
#
# *
# Marcellus: Gitti.
#
# marcellus: gitti.
#
# marcellus gitti.
#
# marcellus*gitti**
#
#
#
#
#
#
# *
# Barnardo: Tam konuşacakken horoz öttü.
#
# barnardo: tam konuşacakken horoz öttü.
#
# barnardo tam konuşacakken horoz öttü.
#
# barnardo*tam*konuşacakken*horoz*öttü**
#
#
#
#
#
#
# *
# Horatio: Ve ürperdi sanki, bir suçlu gibi
#
# horatio: ve ürperdi sanki, bir suçlu gibi
#
# horatio ve ürperdi sanki bir suçlu gibi
#
# horatio*ve*ürperdi*sanki*bir*suçlu*gibi*
#
#
#
#
#
#
# *
# Korktuğu bir çağrıyı duymuş gibi
#
# korktuğu bir çağrıyı duymuş gibi
#
# korktuğu bir çağrıyı duymuş gibi
#
# korktuğu*bir*çağrıyı*duymuş*gibi*
#
#
#
#
#
#
# *
# Kaderin önünde yürür bu haberciler her zaman
#
# kaderin önünde yürür bu haberciler her zaman
#
# kaderin önünde yürür bu haberciler her zaman
#
# kaderin*önünde*yürür*bu*haberciler*her*zaman*
#
#
#
#
#
#
# *
# Yerin, göğün birlikte açtığı
#
# yerin, göğün birlikte açtığı
#
# yerin göğün birlikte açtığı
#
# yerin*göğün*birlikte*açtığı*
#
#
#
#
#
#
# *
# Felaket falları bunlar
#
# felaket falları bunlar
#
# felaket falları bunlar
#
# felaket*falları*bunlar*
#
#
#
#
#
#
# *
# Yurdumuza, yurttaşlarımıza !
#
# yurdumuza, yurttaşlarımıza !
#
# yurdumuza yurttaşlarımıza
#
# yurdumuza*yurttaşlarımıza**
#
#
#
#
#
#
# *
# Bırakalım artık nöbeti ve beni dinlerseniz,
#
# bırakalım artık nöbeti ve beni dinlerseniz,
#
# bırakalım artık nöbeti ve beni dinlerseniz
#
# bırakalım*artık*nöbeti*ve*beni*dinlerseniz*
#
#
#
#
#
#
# *
# Gidip genç Hamlet’e anlatalım
#
# gidip genç hamlet’e anlatalım
#
# gidip genç hamlet’e anlatalım
#
# gidip*genç*hamlet’e*anlatalım*
#
#
#
#
#
#
# *
# Bu gece gördüklerimizi olduğu gibi.
#
# bu gece gördüklerimizi olduğu gibi.
#
# bu gece gördüklerimizi olduğu gibi.
#
# bu*gece*gördüklerimizi*olduğu*gibi**
#
#
#
#
#
#
# *
# Ona sevgimiz de, ödevimiz de bunu gerektirir.
#
# ona sevgimiz de, ödevimiz de bunu gerektirir.
#
# ona sevgimiz de ödevimiz de bunu gerektirir.
#
# ona*sevgimiz*de*ödevimiz*de*bunu*gerektirir**
#
#
#
#
#
#
# *
# Marcellus: Çürümüş bir şeyler var Danimarka’da,
#
# marcellus: Çürümüş bir şeyler var danimarka’da,
#
# marcellus Çürümüş bir şeyler var danimarka’da
#
# marcellus*Çürümüş*bir*şeyler*var*danimarka’da*
#
#
#
#
#
#
# *
# Hayaletler dolaşıyor üzerinde…
#
# hayaletler dolaşıyor üzerinde…
#
# hayaletler dolaşıyor üzerinde…
#
# hayaletler*dolaşıyor*üzerinde…*
#
#
#
#
#
#
# *
# (Alçak sesle bir şölen müziği çalmaya başlar. Sahne arkasından küçük figürlerle, ellerinde maskelerle saray ahalisi girer. Horatio ve diğerleri çıkarlar.)
#
# (alçak sesle bir şölen müziği çalmaya başlar. sahne arkasından küçük figürlerle, ellerinde maskelerle saray ahalisi girer. horatio ve diğerleri çıkarlar.)
#
# alçak sesle bir şölen müziği çalmaya başlar. sahne arkasından küçük figürlerle ellerinde maskelerle saray ahalisi girer. horatio ve diğerleri çıkarlar.
#
# alçak*sesle*bir*şölen*müziği*çalmaya*başlar**sahne*arkasından*küçük*figürlerle*ellerinde*maskelerle*saray*ahalisi*girer**horatio*ve*diğerleri*çıkarlar**
#
#
#
#
#
#
# *
# Anlatıcı: İkinci sahne. Şatonun içinde bir yer. Saray eğleniyor. (Claudius’un yanına gelir). Yeni kral. Ölen kralın kardeşi. Biraz fazla eğlence düşkünü. Üstelik öyle abisi gibi savaşçı niteliklere de sahip değil. Fakat akıllı birine benziyor. Ağabeyinin ölümünden hemen sonra, bazıları genç Hamlet’in kral olmasını beklerken, stratejik bir hamle yapıyor ve ölen kardeşinin eşiyle, yani kraliçe Gertrude ile evleniyor. Bu ilişki kral Hamlet’in ölümünden önce mi başladı yoksa sonra mı? Bu bir tartışma konusu. Ama şunu söyleyebiliriz: Siyasi sonuçları olan ve ahlaki olarak dönemin değerleriyle pek bağdaşmayan bu evlilik soyluların büyük bir kısmı tarafından da destekleniyor.
#
# anlatıcı: İkinci sahne. Şatonun içinde bir yer. saray eğleniyor. (claudius’un yanına gelir). yeni kral. Ölen kralın kardeşi. biraz fazla eğlence düşkünü. Üstelik öyle abisi gibi savaşçı niteliklere de sahip değil. fakat akıllı birine benziyor. ağabeyinin ölümünden hemen sonra, bazıları genç hamlet’in kral olmasını beklerken, stratejik bir hamle yapıyor ve ölen kardeşinin eşiyle, yani kraliçe gertrude ile evleniyor. bu ilişki kral hamlet’in ölümünden önce mi başladı yoksa sonra mı? bu bir tartışma konusu. ama şunu söyleyebiliriz: siyasi sonuçları olan ve ahlaki olarak dönemin değerleriyle pek bağdaşmayan bu evlilik soyluların büyük bir kısmı tarafından da destekleniyor.
#
# anlatıcı İkinci sahne. Şatonun içinde bir yer. saray eğleniyor. claudius’un yanına gelir. yeni kral. Ölen kralın kardeşi. biraz fazla eğlence düşkünü. Üstelik öyle abisi gibi savaşçı niteliklere de sahip değil. fakat akıllı birine benziyor. ağabeyinin ölümünden hemen sonra bazıları genç hamlet’in kral olmasını beklerken stratejik bir hamle yapıyor ve ölen kardeşinin eşiyle yani kraliçe gertrude ile evleniyor. bu ilişki kral hamlet’in ölümünden önce mi başladı yoksa sonra mı bu bir tartışma konusu. ama şunu söyleyebiliriz siyasi sonuçları olan ve ahlaki olarak dönemin değerleriyle pek bağdaşmayan bu evlilik soyluların büyük bir kısmı tarafından da destekleniyor.
#
# anlatıcı*İkinci*sahne**Şatonun*içinde*bir*yer**saray*eğleniyor**claudius’un*yanına*gelir**yeni*kral**Ölen*kralın*kardeşi**biraz*fazla*eğlence*düşkünü**Üstelik*öyle*abisi*gibi*savaşçı*niteliklere*de*sahip*değil**fakat*akıllı*birine*benziyor**ağabeyinin*ölümünden*hemen*sonra*bazıları*genç*hamlet’in*kral*olmasını*beklerken*stratejik*bir*hamle*yapıyor*ve*ölen*kardeşinin*eşiyle*yani*kraliçe*gertrude*ile*evleniyor**bu*ilişki*kral*hamlet’in*ölümünden*önce*mi*başladı*yoksa*sonra*mı*bu*bir*tartışma*konusu**ama*şunu*söyleyebiliriz*siyasi*sonuçları*olan*ve*ahlaki*olarak*dönemin*değerleriyle*pek*bağdaşmayan*bu*evlilik*soyluların*büyük*bir*kısmı*tarafından*da*destekleniyor**
#
#
#
#
#
#
# *
# Saray eğlenedursun Fortinbras “para, pul ve yiyecek aşkına topladığı bir sürü gözü pek haydutla amansız bir saldırıya hazırlanıyor”.
#
# saray eğlenedursun fortinbras “para, pul ve yiyecek aşkına topladığı bir sürü gözü pek haydutla amansız bir saldırıya hazırlanıyor”.
#
# saray eğlenedursun fortinbras “para pul ve yiyecek aşkına topladığı bir sürü gözü pek haydutla amansız bir saldırıya hazırlanıyor”.
#
# saray*eğlenedursun*fortinbras*“para*pul*ve*yiyecek*aşkına*topladığı*bir*sürü*gözü*pek*haydutla*amansız*bir*saldırıya*hazırlanıyor”**
#
#
#
#
#
#
# *
# Claudius: Müteveffa kardeşimiz çok aziz Hamlet’in
#
# claudius: müteveffa kardeşimiz çok aziz hamlet’in
#
# claudius müteveffa kardeşimiz çok aziz hamlet’in
#
# claudius*müteveffa*kardeşimiz*çok*aziz*hamlet’in*
#
#
#
#
#
#
# *
# Derin acısı her ne kadar tazeyse de anımızda
#
# derin acısı her ne kadar tazeyse de anımızda
#
# derin acısı her ne kadar tazeyse de anımızda
#
# derin*acısı*her*ne*kadar*tazeyse*de*anımızda*
#
#
#
#
#
#
# *
# Ve kederden çatılmış bir çift kaş gibi milletçe
#
# ve kederden çatılmış bir çift kaş gibi milletçe
#
# ve kederden çatılmış bir çift kaş gibi milletçe
#
# ve*kederden*çatılmış*bir*çift*kaş*gibi*milletçe*
#
#
#
#
#
#
# *
# Sabırla ve tevekkülle yasta kusur etmiyorsak da,
#
# sabırla ve tevekkülle yasta kusur etmiyorsak da,
#
# sabırla ve tevekkülle yasta kusur etmiyorsak da
#
# sabırla*ve*tevekkülle*yasta*kusur*etmiyorsak*da*
#
#
#
#
#
#
# *
# Akl-ı selimi elden bırakmaksızın bugüne kadar
#
# akl-ı selimi elden bırakmaksızın bugüne kadar
#
# aklı selimi elden bırakmaksızın bugüne kadar
#
# aklı*selimi*elden*bırakmaksızın*bugüne*kadar*
#
#
#
#
#
#
# *
# Nasıl içimiz titreyerek düşünmekteysek de O’nu,
#
# nasıl içimiz titreyerek düşünmekteysek de o’nu,
#
# nasıl içimiz titreyerek düşünmekteysek de o’nu
#
# nasıl*içimiz*titreyerek*düşünmekteysek*de*o’nu*
#
#
#
#
#
#
# *
# Kendimizi de unutmayalım diyoruz artık.
#
# kendimizi de unutmayalım diyoruz artık.
#
# kendimizi de unutmayalım diyoruz artık.
#
# kendimizi*de*unutmayalım*diyoruz*artık**
#
#
#
#
#
#
# *
# Onun için, eski kardeşimiz, bugünkü kraliçemizle
#
# onun için, eski kardeşimiz, bugünkü kraliçemizle
#
# onun için eski kardeşimiz bugünkü kraliçemizle
#
# onun*için*eski*kardeşimiz*bugünkü*kraliçemizle*
#
#
#
#
#
#
# *
# Bu yiğit memleketin taç ortağı olan kadınla
#
# bu yiğit memleketin taç ortağı olan kadınla
#
# bu yiğit memleketin taç ortağı olan kadınla
#
# bu*yiğit*memleketin*taç*ortağı*olan*kadınla*
#
#
#
#
#
#
# *
# Bir gözümüz ağlayıp, bir gözümüz gülerek,
#
# bir gözümüz ağlayıp, bir gözümüz gülerek,
#
# bir gözümüz ağlayıp bir gözümüz gülerek
#
# bir*gözümüz*ağlayıp*bir*gözümüz*gülerek*
#
#
#
#
#
#
# *
# Düğünde cenaze, cenazede düğün türküleri söyleyerek
#
# düğünde cenaze, cenazede düğün türküleri söyleyerek
#
# düğünde cenaze cenazede düğün türküleri söyleyerek
#
# düğünde*cenaze*cenazede*düğün*türküleri*söyleyerek*
#
#
#
#
#
#
# *
# Ve tartarak aynı kantarda dert ile zevki
#
# ve tartarak aynı kantarda dert ile zevki
#
# ve tartarak aynı kantarda dert ile zevki
#
# ve*tartarak*aynı*kantarda*dert*ile*zevki*
#
#
#
#
#
#
# *
# Evlendik bugüne bugün…sizlere de danışarak elbet
#
# evlendik bugüne bugün…sizlere de danışarak elbet
#
# evlendik bugüne bugün…sizlere de danışarak elbet
#
# evlendik*bugüne*bugün…sizlere*de*danışarak*elbet*
#
#
#
#
#
#
# *
# Ve sizler de yalnız kendi vicdanınızı dinleyerek
#
# ve sizler de yalnız kendi vicdanınızı dinleyerek
#
# ve sizler de yalnız kendi vicdanınızı dinleyerek
#
# ve*sizler*de*yalnız*kendi*vicdanınızı*dinleyerek*
#
#
#
#
#
#
# *
# Hak verdiniz bize: Teşekkürler hepinize!
#
# hak verdiniz bize: teşekkürler hepinize!
#
# hak verdiniz bize teşekkürler hepinize
#
# hak*verdiniz*bize*teşekkürler*hepinize*
#
#
#
#
#
#
# *
# Şimdi gelelim diğer meselemize: Fortinbras’ın oğlu
#
# Şimdi gelelim diğer meselemize: fortinbras’ın oğlu
#
# Şimdi gelelim diğer meselemize fortinbras’ın oğlu
#
# Şimdi*gelelim*diğer*meselemize*fortinbras’ın*oğlu*
#
#
#
#
#
#
# *
# Kudret-i kuvvetimizi yumurta sepeti sanarak
#
# kudret-i kuvvetimizi yumurta sepeti sanarak
#
# kudreti kuvvetimizi yumurta sepeti sanarak
#
# kudreti*kuvvetimizi*yumurta*sepeti*sanarak*
#
#
#
#
#
#
# *
# Ya da toprağı bol kardeşimizin ölmesiyle
#
# ya da toprağı bol kardeşimizin ölmesiyle
#
# ya da toprağı bol kardeşimizin ölmesiyle
#
# ya*da*toprağı*bol*kardeşimizin*ölmesiyle*
#
#
#
#
#
#
# *
# Devletimiz göçtü, çöktü belleyerek
#
# devletimiz göçtü, çöktü belleyerek
#
# devletimiz göçtü çöktü belleyerek
#
# devletimiz*göçtü*çöktü*belleyerek*
#
#
#
#
#
#
# *
# Bir ordu toplamış hayale kaptırıp kendini.
#
# bir ordu toplamış hayale kaptırıp kendini.
#
# bir ordu toplamış hayale kaptırıp kendini.
#
# bir*ordu*toplamış*hayale*kaptırıp*kendini**
#
#
#
#
#
#
# *
# Durmadan başımızı ağrıtır oldu elçileriyle,
#
# durmadan başımızı ağrıtır oldu elçileriyle,
#
# durmadan başımızı ağrıtır oldu elçileriyle
#
# durmadan*başımızı*ağrıtır*oldu*elçileriyle*
#
#
#
#
#
#
# *
# Babasının yitirdiği
#
# babasının yitirdiği
#
# babasının yitirdiği
#
# babasının*yitirdiği*
#
#
#
#
#
#
# *
# Ve yiğit kardeşimizin yasalarla kazandığı
#
# ve yiğit kardeşimizin yasalarla kazandığı
#
# ve yiğit kardeşimizin yasalarla kazandığı
#
# ve*yiğit*kardeşimizin*yasalarla*kazandığı*
#
#
#
#
#
#
# *
# Toprakları geri ister… O isteye dursun
#
# toprakları geri ister… o isteye dursun
#
# toprakları geri ister… o isteye dursun
#
# toprakları*geri*ister…*o*isteye*dursun*
#
#
#
#
#
#
# *
# Bu toplantıda bizim asıl söylemek istediğimiz şudur size:
#
# bu toplantıda bizim asıl söylemek istediğimiz şudur size:
#
# bu toplantıda bizim asıl söylemek istediğimiz şudur size
#
# bu*toplantıda*bizim*asıl*söylemek*istediğimiz*şudur*size*
#
#
#
#
#
#
# *
# Bir mektup yazdık genç Fortinbras’ın amcası Norveç Kralı’na,
#
# bir mektup yazdık genç fortinbras’ın amcası norveç kralı’na,
#
# bir mektup yazdık genç fortinbras’ın amcası norveç kralı’na
#
# bir*mektup*yazdık*genç*fortinbras’ın*amcası*norveç*kralı’na*
#
#
#
#
#
#
# *
# Yeğeninin ne işler çevirdiğinden habersiz olan o zavallı yatalağa,
#
# yeğeninin ne işler çevirdiğinden habersiz olan o zavallı yatalağa,
#
# yeğeninin ne işler çevirdiğinden habersiz olan o zavallı yatalağa
#
# yeğeninin*ne*işler*çevirdiğinden*habersiz*olan*o*zavallı*yatalağa*
#
#
#
#
#
#
# *
# Dizginlesin diye bu dolu-dizgin girişimi.
#
# dizginlesin diye bu dolu-dizgin girişimi.
#
# dizginlesin diye bu doludizgin girişimi.
#
# dizginlesin*diye*bu*doludizgin*girişimi**
#
#
#
#
#
#
# *
# Ne de olsa onun uyrukları toplanan askerler.
#
# ne de olsa onun uyrukları toplanan askerler.
#
# ne de olsa onun uyrukları toplanan askerler.
#
# ne*de*olsa*onun*uyrukları*toplanan*askerler**
#
#
#
#
#
#
# *
# Savaş için gerekli özel müfrezeler onun elinde.
#
# savaş için gerekli özel müfrezeler onun elinde.
#
# savaş için gerekli özel müfrezeler onun elinde.
#
# savaş*için*gerekli*özel*müfrezeler*onun*elinde**
#
#
#
#
#
#
# *
# Bu iş için siz, dostlarım, Cornelius ve Voltimand,
#
# bu iş için siz, dostlarım, cornelius ve voltimand,
#
# bu iş için siz dostlarım cornelius ve voltimand
#
# bu*iş*için*siz*dostlarım*cornelius*ve*voltimand*
#
#
#
#
#
#
# *
# Sizleri yolluyorum ihtiyar Norveç Kralı’na.
#
# sizleri yolluyorum ihtiyar norveç kralı’na.
#
# sizleri yolluyorum ihtiyar norveç kralı’na.
#
# sizleri*yolluyorum*ihtiyar*norveç*kralı’na**
#
#
#
#
#
#
# *
# Yalnız burada kayıtlı maddeler haricinde
#
# yalnız burada kayıtlı maddeler haricinde
#
# yalnız burada kayıtlı maddeler haricinde
#
# yalnız*burada*kayıtlı*maddeler*haricinde*
#
#
#
#
#
#
# *
# Kralla görüşmeye herhangi bir şekilde
#
# kralla görüşmeye herhangi bir şekilde
#
# kralla görüşmeye herhangi bir şekilde
#
# kralla*görüşmeye*herhangi*bir*şekilde*
#
#
#
#
#
#
# *
# Şahsen yetkili değilsiniz anlaşıldı mı?
#
# Şahsen yetkili değilsiniz anlaşıldı mı?
#
# Şahsen yetkili değilsiniz anlaşıldı mı
#
# Şahsen*yetkili*değilsiniz*anlaşıldı*mı*
#
#
#
#
#
#
# *
# Ayağınız tez, eliniz titiz olsun!
#
# ayağınız tez, eliniz titiz olsun!
#
# ayağınız tez eliniz titiz olsun
#
# ayağınız*tez*eliniz*titiz*olsun*
#
#
#
#
#
#
# *
# Cornelius ve Voltimand: Her zaman ve her işte bağlıyız size.
#
# cornelius ve voltimand: her zaman ve her işte bağlıyız size.
#
# cornelius ve voltimand her zaman ve her işte bağlıyız size.
#
# cornelius*ve*voltimand*her*zaman*ve*her*işte*bağlıyız*size**
#
#
#
#
#
#
# *
# Claudius: Ona ne şüphe! Yolunuz açık olsun.
#
# claudius: ona ne şüphe! yolunuz açık olsun.
#
# claudius ona ne şüphe yolunuz açık olsun.
#
# claudius*ona*ne*şüphe*yolunuz*açık*olsun**
#
#
#
#
#
#
# *
# Gel bakalım Laertes! Nasılsın iyi misin?
#
# gel bakalım laertes! nasılsın iyi misin?
#
# gel bakalım laertes nasılsın iyi misin
#
# gel*bakalım*laertes*nasılsın*iyi*misin*
#
#
#
#
#
#
# *
# Bir arzum var demiştin, sahi neydi o Laertes?
#
# bir arzum var demiştin, sahi neydi o laertes?
#
# bir arzum var demiştin sahi neydi o laertes
#
# bir*arzum*var*demiştin*sahi*neydi*o*laertes*
#
#
#
#
#
#
# *
# Yeter ki akla yakın bir şey olsun istenilen,
#
# yeter ki akla yakın bir şey olsun istenilen,
#
# yeter ki akla yakın bir şey olsun istenilen
#
# yeter*ki*akla*yakın*bir*şey*olsun*istenilen*
#
#
#
#
#
#
# *
# Reddettiği görülmüş mü zatımın?
#
# reddettiği görülmüş mü zatımın?
#
# reddettiği görülmüş mü zatımın
#
# reddettiği*görülmüş*mü*zatımın*
#
#
#
#
#
#
# *
# Kafa yüreğe, el ağza bağlı değildir
#
# kafa yüreğe, el ağza bağlı değildir
#
# kafa yüreğe el ağza bağlı değildir
#
# kafa*yüreğe*el*ağza*bağlı*değildir*
#
#
#
#
#
#
# *
# Senin babanın bize bağlı olduğu kadar.
#
# senin babanın bize bağlı olduğu kadar.
#
# senin babanın bize bağlı olduğu kadar.
#
# senin*babanın*bize*bağlı*olduğu*kadar**
#
#
#
#
#
#
# *
# Nedir dileğin, söyle Laertes?
#
# nedir dileğin, söyle laertes?
#
# nedir dileğin söyle laertes
#
# nedir*dileğin*söyle*laertes*
#
#
#
#
#
#
# *
# Laertes: Dileğim Fransa’ya dönmek, Haşmetli Kralım.
#
# laertes: dileğim fransa’ya dönmek, haşmetli kralım.
#
# laertes dileğim fransa’ya dönmek haşmetli kralım.
#
# laertes*dileğim*fransa’ya*dönmek*haşmetli*kralım**
#
#
#
#
#
#
# *
# Taç giyme töreninize katılmak için
#
# taç giyme töreninize katılmak için
#
# taç giyme töreninize katılmak için
#
# taç*giyme*töreninize*katılmak*için*
#
#
#
#
#
#
# *
# Uça uça geldim Danimarka’ya.
#
# uça uça geldim danimarka’ya.
#
# uça uça geldim danimarka’ya.
#
# uça*uça*geldim*danimarka’ya**
#
#
#
#
#
#
# *
# Ama bu ödevimi yerine getirdikten sonra
#
# ama bu ödevimi yerine getirdikten sonra
#
# ama bu ödevimi yerine getirdikten sonra
#
# ama*bu*ödevimi*yerine*getirdikten*sonra*
#
#
#
#
#
#
# *
# Lütufkar affınıza ve izninize sığınarak, itiraf etmeliyim ki,
#
# lütufkar affınıza ve izninize sığınarak, itiraf etmeliyim ki,
#
# lütufkar affınıza ve izninize sığınarak itiraf etmeliyim ki
#
# lütufkar*affınıza*ve*izninize*sığınarak*itiraf*etmeliyim*ki*
#
#
#
#
#
#
# *
# Aklım ve yüreğim Paris’e dönmekte Kralım.
#
# aklım ve yüreğim paris’e dönmekte kralım.
#
# aklım ve yüreğim paris’e dönmekte kralım.
#
# aklım*ve*yüreğim*paris’e*dönmekte*kralım**
#
#
#
#
#
#
# *
# Claudius: Babanın izni var mı peki? Sen ne diyorsun Polonius?
#
# claudius: babanın izni var mı peki? sen ne diyorsun polonius?
#
# claudius babanın izni var mı peki sen ne diyorsun polonius
#
# claudius*babanın*izni*var*mı*peki*sen*ne*diyorsun*polonius*
#
#
#
#
#
#
# *
# Polonius: Bin bir ısrarla, efendimiz, yalvar yakar
#
# polonius: bin bir ısrarla, efendimiz, yalvar yakar
#
# polonius bin bir ısrarla efendimiz yalvar yakar
#
# polonius*bin*bir*ısrarla*efendimiz*yalvar*yakar*
#
#
#
#
#
#
# *
# İzni kopardı benden. Arzumun hilafına rağmen
#
# İzni kopardı benden. arzumun hilafına rağmen
#
# İzni kopardı benden. arzumun hilafına rağmen
#
# İzni*kopardı*benden**arzumun*hilafına*rağmen*
#
#
#
#
#
#
# *
# Kıramadım arzusunu.
#
# kıramadım arzusunu.
#
# kıramadım arzusunu.
#
# kıramadım*arzusunu**
#
#
#
#
#
#
# *
# Kerem edin siz de, verin gitsin izninizi.
#
# kerem edin siz de, verin gitsin izninizi.
#
# kerem edin siz de verin gitsin izninizi.
#
# kerem*edin*siz*de*verin*gitsin*izninizi**
#
#
#
#
#
#
# *
# Claudius: (bir süre izin vermeyecekmiş gibi bir tutum takınır “bilmiyorum ki şimdi, ülkenin içinde bulunduğu bu zor zamanlarda, senin gibi birini kaybetmek…”, sonra espri yaptığını açığa vurur.)
#
# claudius: (bir süre izin vermeyecekmiş gibi bir tutum takınır “bilmiyorum ki şimdi, ülkenin içinde bulunduğu bu zor zamanlarda, senin gibi birini kaybetmek…”, sonra espri yaptığını açığa vurur.)
#
# claudius bir süre izin vermeyecekmiş gibi bir tutum takınır “bilmiyorum ki şimdi ülkenin içinde bulunduğu bu zor zamanlarda senin gibi birini kaybetmek…” sonra espri yaptığını açığa vurur.
#
# claudius*bir*süre*izin*vermeyecekmiş*gibi*bir*tutum*takınır*“bilmiyorum*ki*şimdi*ülkenin*içinde*bulunduğu*bu*zor*zamanlarda*senin*gibi*birini*kaybetmek…”*sonra*espri*yaptığını*açığa*vurur**
#
#
#
#
#
#
# *
# Güle güle git Laertes, gününü gün et.
#
# güle güle git laertes, gününü gün et.
#
# güle güle git laertes gününü gün et.
#
# güle*güle*git*laertes*gününü*gün*et**
#
#
#
#
#
#
# *
# Gönlünce tadını çıkar gençliğinin.
#
# gönlünce tadını çıkar gençliğinin.
#
# gönlünce tadını çıkar gençliğinin.
#
# gönlünce*tadını*çıkar*gençliğinin**
#
#
#
#
#
#
# *
# (Claudius ve Hamlet göz göze gelirler.)
#
# (claudius ve hamlet göz göze gelirler.)
#
# claudius ve hamlet göz göze gelirler.
#
# claudius*ve*hamlet*göz*göze*gelirler**
#
#
#
#
#
#
# *
# Claudius: Ya sen, yeğenimiz Hamlet ve de oğlumuz…
#
# claudius: ya sen, yeğenimiz hamlet ve de oğlumuz…
#
# claudius ya sen yeğenimiz hamlet ve de oğlumuz…
#
# claudius*ya*sen*yeğenimiz*hamlet*ve*de*oğlumuz…*
#
#
#
#
#
#
# *
# Hamlet: Yeğenden biraz fazla, oğuldan bir hayli az.
#
# hamlet: yeğenden biraz fazla, oğuldan bir hayli az.
#
# hamlet yeğenden biraz fazla oğuldan bir hayli az.
#
# ...
#
# ama et ve kandan kulaklara duymak yok
#
# ama*et*ve*kandan*kulaklara*duymak*yok*
#
#
#
#
#
#
# *
# Ruhlar dünyasının sırlarını.
#
# ruhlar dünyasının sırlarını.
#
# ruhlar dünyasının sırlarını.
#
# ruhlar*dünyasının*sırlarını**
#
#
#
#
#
#
# *
# Dinle, dinle ama, dinle!
#
# dinle, dinle ama, dinle!
#
# dinle dinle ama dinle
#
# dinle*dinle*ama*dinle*
#
#
#
#
#
#
# *
# Sevgili Babanı gerçekten sevdinse eğer…
#
# sevgili babanı gerçekten sevdinse eğer…
#
# sevgili babanı gerçekten sevdinse eğer…
#
# sevgili*babanı*gerçekten*sevdinse*eğer…*
#
#
#
#
#
#
# *
# Alçakça, canavarca öldürülmesinin öcünü al.
#
# alçakça, canavarca öldürülmesinin öcünü al.
#
# alçakça canavarca öldürülmesinin öcünü al.
#
# alçakça*canavarca*öldürülmesinin*öcünü*al**
#
#
#
#
#
#
# *
# (Müzik kesilir. Sessizlik.)
#
# (müzik kesilir. sessizlik.)
#
# müzik kesilir. sessizlik.
#
# müzik*kesilir**sessizlik**
#
#
#
#
#
#
# *
# Hamlet: Öldürülmesi mi?
#
# hamlet: Öldürülmesi mi?
#
# hamlet Öldürülmesi mi
#
# hamlet*Öldürülmesi*mi*
#
#
#
#
#
#
# *
# Anlat çabuk! Anlat ki koşayım öcünü almaya.
#
# anlat çabuk! anlat ki koşayım öcünü almaya.
#
# anlat çabuk anlat ki koşayım öcünü almaya.
#
# anlat*çabuk*anlat*ki*koşayım*öcünü*almaya**
#
#
#
#
#
#
# *
# Hayalet: Hamlet, duysun şunu kulakların:
#
# hayalet: hamlet, duysun şunu kulakların:
#
# hayalet hamlet duysun şunu kulakların
#
# hayalet*hamlet*duysun*şunu*kulakların*
#
#
#
#
#
#
# *
# Beni yılan sokmuş dediler bağ köşkümde uyurken,
#
# beni yılan sokmuş dediler bağ köşkümde uyurken,
#
# beni yılan sokmuş dediler bağ köşkümde uyurken
#
# beni*yılan*sokmuş*dediler*bağ*köşkümde*uyurken*
#
#
#
#
#
#
# *
# Bütün Danimarka’yı düpedüz aldattılar
#
# bütün danimarka’yı düpedüz aldattılar
#
# bütün danimarka’yı düpedüz aldattılar
#
# bütün*danimarka’yı*düpedüz*aldattılar*
#
#
#
#
#
#
# *
# Ölümüme böyle bir sebep uydurarak.
#
# Ölümüme böyle bir sebep uydurarak.
#
# Ölümüme böyle bir sebep uydurarak.
#
# Ölümüme*böyle*bir*sebep*uydurarak**
#
#
#
#
#
#
# *
# Ama şunu bil ki soylu oğlum benim,
#
# ama şunu bil ki soylu oğlum benim,
#
# ama şunu bil ki soylu oğlum benim
#
# ama*şunu*bil*ki*soylu*oğlum*benim*
#
#
#
#
#
#
# *
# Babanın canına kıyan yılan
#
# babanın canına kıyan yılan
#
# babanın canına kıyan yılan
#
# babanın*canına*kıyan*yılan*
#
#
#
#
#
#
# *
# Onun tacını giyiyor şimdi…
#
# onun tacını giyiyor şimdi…
#
# onun tacını giyiyor şimdi…
#
# onun*tacını*giyiyor*şimdi…*
#
#
#
#
#
#
# *
# Hayalet: Ey bilinmeyeni bilen ruhum benim!
#
# hayalet: ey bilinmeyeni bilen ruhum benim!
#
# hayalet ey bilinmeyeni bilen ruhum benim
#
# hayalet*ey*bilinmeyeni*bilen*ruhum*benim*
#
#
#
#
#
#
# *
# Amcam demek!
#
# amcam demek!
#
# amcam demek
#
# amcam*demek*
#
#
#
#
#
#
# *
# Hayalet: Evet, o haram arzulara susamış hayvan,
#
# hayalet: evet, o haram arzulara susamış hayvan,
#
# hayalet evet o haram arzulara susamış hayvan
#
# hayalet*evet*o*haram*arzulara*susamış*hayvan*
#
#
#
#
#
#
# *
# Sihirbaz oyunlarıyla , şeytanca hediyelerle
#
# sihirbaz oyunlarıyla , şeytanca hediyelerle
#
# sihirbaz oyunlarıyla  şeytanca hediyelerle
#
# sihirbaz*oyunlarıyla**şeytanca*hediyelerle*
#
#
#
#
#
#
# *
# İğrenç emellerine çeldi yüreğini
#
# İğrenç emellerine çeldi yüreğini
#
# İğrenç emellerine çeldi yüreğini
#
# İğrenç*emellerine*çeldi*yüreğini*
#
#
#
#
#
#
# *
# O melek görünüşlü kraliçemin!
#
# o melek görünüşlü kraliçemin!
#
# o melek görünüşlü kraliçemin
#
# o*melek*görünüşlü*kraliçemin*
#
#
#
#
#
#
# *
# Bağ köşkünde uyurken ben,
#
# bağ köşkünde uyurken ben,
#
# bağ köşkünde uyurken ben
#
# bağ*köşkünde*uyurken*ben*
#
#
#
#
#
#
# *
# Her öğleden sonra uyuduğum gibi;
#
# her öğleden sonra uyuduğum gibi;
#
# her öğleden sonra uyuduğum gibi
#
# her*öğleden*sonra*uyuduğum*gibi*
#
#
#
#
#
#
# *
# Amcan, o kuşkusuz rahat saatimde,
#
# amcan, o kuşkusuz rahat saatimde,
#
# amcan o kuşkusuz rahat saatimde
#
# amcan*o*kuşkusuz*rahat*saatimde*
#
#
#
#
#
#
# *
# Sinsi adımlarla geldi yanıma
#
# sinsi adımlarla geldi yanıma
#
# sinsi adımlarla geldi yanıma
#
# sinsi*adımlarla*geldi*yanıma*
#
#
#
#
#
#
# *
# Elinde yaman bir zehir şişesi,
#
# elinde yaman bir zehir şişesi,
#
# elinde yaman bir zehir şişesi
#
# elinde*yaman*bir*zehir*şişesi*
#
#
#
#
#
#
# *
# Kulaklarımdan cüzzamlar akıttı içime.
#
# kulaklarımdan cüzzamlar akıttı içime.
#
# kulaklarımdan cüzzamlar akıttı içime.
#
# kulaklarımdan*cüzzamlar*akıttı*içime**
#
#
#
#
#
#
# *
# Böyle yitirdim canımı, tacımı, kraliçemi,
#
# böyle yitirdim canımı, tacımı, kraliçemi,
#
# böyle yitirdim canımı tacımı kraliçemi
#
# böyle*yitirdim*canımı*tacımı*kraliçemi*
#
#
#
#
#
#
# *
# Bir anda uyurken, kardeş eliyle.
#
# bir anda uyurken, kardeş eliyle.
#
# bir anda uyurken kardeş eliyle.
#
# bir*anda*uyurken*kardeş*eliyle**
#
#
#
#
#
#
# *
# Kanın coşkun akıyorsa eğer damarlarından,
#
# kanın coşkun akıyorsa eğer damarlarından,
#
# kanın coşkun akıyorsa eğer damarlarından
#
# kanın*coşkun*akıyorsa*eğer*damarlarından*
#
#
#
#
#
#
# *
# Boyun eğme olup bitenlere!
#
# boyun eğme olup bitenlere!
#
# boyun eğme olup bitenlere
#
# boyun*eğme*olup*bitenlere*
#
#
#
#
#
#
# *
# İzin verme Danimarka tahtının
#
# İzin verme danimarka tahtının
#
# İzin verme danimarka tahtının
#
# İzin*verme*danimarka*tahtının*
#
#
#
#
#
#
# *
# Lanetli bir haram döşeği olmasına!
#
# lanetli bir haram döşeği olmasına!
#
# lanetli bir haram döşeği olmasına
#
# lanetli*bir*haram*döşeği*olmasına*
#
#
#
#
#
#
# *
# Ama yapacağını ne türlü yaparsan yap,
#
# ama yapacağını ne türlü yaparsan yap,
#
# ama yapacağını ne türlü yaparsan yap
#
# ama*yapacağını*ne*türlü*yaparsan*yap*
#
#
#
#
#
#
# *
# Anana el kaldırıp kirletme elini!
#
# anana el kaldırıp kirletme elini!
#
# anana el kaldırıp kirletme elini
#
# anana*el*kaldırıp*kirletme*elini*
#
#
#
#
#
#
# *
# Bırak tanrı görsün hesabını,
#
# bırak tanrı görsün hesabını,
#
# bırak tanrı görsün hesabını
#
# bırak*tanrı*görsün*hesabını*
#
#
#
#
#
#
# *
# Kendi içindeki dikenler kanatsın vicdanını!
#
# kendi içindeki dikenler kanatsın vicdanını!
#
# kendi içindeki dikenler kanatsın vicdanını
#
# kendi*içindeki*dikenler*kanatsın*vicdanını*
#
#
#
#
#
#
# *
# Artık gitmeliyim, tanrıya emanet ol!
#
# artık gitmeliyim, tanrıya emanet ol!
#
# artık gitmeliyim tanrıya emanet ol
#
# artık*gitmeliyim*tanrıya*emanet*ol*
#
#
#
#
#
#
# *
# Sakın unutma beni!
#
# sakın unutma beni!
#
# sakın unutma beni
#
# sakın*unutma*beni*
#
#
#
#
#
#
# *
# Hamlet: Ey göklerde yaşayanlar! Ey dünya! Daha ne olsun?
#
# hamlet: ey göklerde yaşayanlar! ey dünya! daha ne olsun?
#
# hamlet ey göklerde yaşayanlar ey dünya daha ne olsun
#
# hamlet*ey*göklerde*yaşayanlar*ey*dünya*daha*ne*olsun*
#
#
#
#
#
#
# *
# Cehennem önüne mi gelsin? Ne yüz karası şey bu?
#
# cehennem önüne mi gelsin? ne yüz karası şey bu?
#
# cehennem önüne mi gelsin ne yüz karası şey bu
#
# cehennem*önüne*mi*gelsin*ne*yüz*karası*şey*bu*
#
#
#
#
#
#
# *
# Tut kendini yüreğim, tut kendini!
#
# tut kendini yüreğim, tut kendini!
#
# tut kendini yüreğim tut kendini
#
# tut*kendini*yüreğim*tut*kendini*
#
#
#
#
#
#
# *
# Ey çürümüş yürekli kadın!
#
# ey çürümüş yürekli kadın!
#
# ey çürümüş yürekli kadın
#
# ey*çürümüş*yürekli*kadın*
#
#
#
#
#
#
# *
# Yaz aklım, yaz defterine, yaz şunu:
#
# yaz aklım, yaz defterine, yaz şunu:
#
# yaz aklım yaz defterine yaz şunu
#
# yaz*aklım*yaz*defterine*yaz*şunu*
#
#
#
#
#
#
# *
# Güler yüzlü, hep güler yüzlü bir insan
#
# güler yüzlü, hep güler yüzlü bir insan
#
# güler yüzlü hep güler yüzlü bir insan
#
# güler*yüzlü*hep*güler*yüzlü*bir*insan*
#
#
#
#
#
#
# *
# Zehirli bir yılan da olabilir.
#
# zehirli bir yılan da olabilir.
#
# zehirli bir yılan da olabilir.
#
# zehirli*bir*yılan*da*olabilir**
#
#
#
#
#
#
# *
# Ya! Demek böyle, amca, sen buymuşsun demek!
#
# ya! demek böyle, amca, sen buymuşsun demek!
#
# ya demek böyle amca sen buymuşsun demek
#
# ya*demek*böyle*amca*sen*buymuşsun*demek*
#
#
#
#
#
#
# *
# Öyleyse, benim parolam da şu bundan böyle:
#
# Öyleyse, benim parolam da şu bundan böyle:
#
# Öyleyse benim parolam da şu bundan böyle
#
# Öyleyse*benim*parolam*da*şu*bundan*böyle*
#
#
#
#
#
#
# *
# Tanrı, seninle olsun, unutma beni!
#
# tanrı, seninle olsun, unutma beni!
#
# tanrı seninle olsun unutma beni
#
# tanrı*seninle*olsun*unutma*beni*
#
#
#
#
#
#
# *
# Yemin ettim, unutmam.
#
# yemin ettim, unutmam.
#
# yemin ettim unutmam.
#
# yemin*ettim*unutmam**
#
#
#
#
#
#
# *
# (Horatio ve diğerleri soluk soluğa gelirler.)
#
# (horatio ve diğerleri soluk soluğa gelirler.)
#
# horatio ve diğerleri soluk soluğa gelirler.
#
# horatio*ve*diğerleri*soluk*soluğa*gelirler**
#
#
#
#
#
#
# *
# Marcellus: Neler oldu Lordum? İyi misiniz?
#
# marcellus: neler oldu lordum? İyi misiniz?
#
# marcellus neler oldu lordum İyi misiniz
#
# marcellus*neler*oldu*lordum*İyi*misiniz*
#
#
#
#
#
#
# *
# Barnardo: Hayaletin peşinden koşturup gidince siz efendimiz,
#
# barnardo: hayaletin peşinden koşturup gidince siz efendimiz,
#
# barnardo hayaletin peşinden koşturup gidince siz efendimiz
#
# barnardo*hayaletin*peşinden*koşturup*gidince*siz*efendimiz*
#
#
#
#
#
#
# *
# Yitirdik izinizi.
#
# yitirdik izinizi.
#
# yitirdik izinizi.
#
# yitirdik*izinizi**
#
#
#
#
#
#
# *
# Horatio: Söylesenize neler oldu?
#
# horatio: söylesenize neler oldu?
#
# horatio söylesenize neler oldu
#
# horatio*söylesenize*neler*oldu*
#
#
#
#
#
#
# *
# Hamlet: Olacak şey mi bu söyleyin?
#
# hamlet: olacak şey mi bu söyleyin?
#
# hamlet olacak şey mi bu söyleyin
#
# hamlet*olacak*şey*mi*bu*söyleyin*
#
#
#
#
#
#
# *
# İnsanın aklına gelir miydi hiç bu?
#
# İnsanın aklına gelir miydi hiç bu?
#
# İnsanın aklına gelir miydi hiç bu
#
# İnsanın*aklına*gelir*miydi*hiç*bu*
#
#
#
#
#
#
# *
# Aramızda kalacak değil mi?
#
# aramızda kalacak değil mi?
#
# aramızda kalacak değil mi
#
# aramızda*kalacak*değil*mi*
#
#
#
#
#
#
# *
# Horatio-Marcellus: Ona ne şüphe efendimiz
#
# horatio-marcellus: ona ne şüphe efendimiz
#
# horatiomarcellus ona ne şüphe efendimiz
#
# horatiomarcellus*ona*ne*şüphe*efendimiz*
#
#
#
#
#
#
# *
# Hamlet: Bir iblis varmış, bir tek iblis bütün Danimarka’da,
#
# hamlet: bir iblis varmış, bir tek iblis bütün danimarka’da,
#
# hamlet bir iblis varmış bir tek iblis bütün danimarka’da
#
# hamlet*bir*iblis*varmış*bir*tek*iblis*bütün*danimarka’da*
#
#
#
#
#
#
# *
# Alçak namussuzun biri.
#
# alçak namussuzun biri.
#
# alçak namussuzun biri.
#
# alçak*namussuzun*biri**
#
#
#
#
#
#
# *
# Horatio: Bize bunu söylemek için, efendimiz
#
# horatio: bize bunu söylemek için, efendimiz
#
# horatio bize bunu söylemek için efendimiz
#
# horatio*bize*bunu*söylemek*için*efendimiz*
#
#
#
#
#
#
# *
# Bir ölünün mezarından çıkmasına lüzum yoktu.
#
# bir ölünün mezarından çıkmasına lüzum yoktu.
#
# bir ölünün mezarından çıkmasına lüzum yoktu.
#
# bir*ölünün*mezarından*çıkmasına*lüzum*yoktu**
#
#
#
#
#
#
# *
# Hamlet: Evet doğru! Çok haklısın!
#
# hamlet: evet doğru! Çok haklısın!
#
# hamlet evet doğru Çok haklısın
#
# hamlet*evet*doğru*Çok*haklısın*
#
#
#
#
#
#
# *
# Onun için hiç kurcalamadan bu işi,
#
# onun için hiç kurcalamadan bu işi,
#
# onun için hiç kurcalamadan bu işi
#
# onun*için*hiç*kurcalamadan*bu*işi*
#
#
#
#
#
#
# *
# El sıkışıp ayrılalım en iyisi.
#
# el sıkışıp ayrılalım en iyisi.
#
# el sıkışıp ayrılalım en iyisi.
#
# el*sıkışıp*ayrılalım*en*iyisi**
#
#
#
#
#
#
# *
# Siz işinize keyfinize bakın artık,
#
# siz işinize keyfinize bakın artık,
#
# siz işinize keyfinize bakın artık
#
# siz*işinize*keyfinize*bakın*artık*
#
#
#
#
#
#
# *
# Herkesin bir işi, bir keyfi var, değil mi ya?
#
# herkesin bir işi, bir keyfi var, değil mi ya?
#
# herkesin bir işi bir keyfi var değil mi ya
#
# herkesin*bir*işi*bir*keyfi*var*değil*mi*ya*
#
#
#
#
#
#
# *
# Bana gelince ben gidip dua edeceğim.
#
# bana gelince ben gidip dua edeceğim.
#
# bana gelince ben gidip dua edeceğim.
#
# bana*gelince*ben*gidip*dua*edeceğim**
#
#
#
#
#
#
# *
# Horatio: Bunlar bit tuhaf, tutarsız sözler, efendimiz.
#
# horatio: bunlar bit tuhaf, tutarsız sözler, efendimiz.
#
# horatio bunlar bit tuhaf tutarsız sözler efendimiz.
#
# horatio*bunlar*bit*tuhaf*tutarsız*sözler*efendimiz**
#
#
#
#
#
#
# *
# Hamlet: Özür dilerim kırdımsa sizin.
#
# hamlet: Özür dilerim kırdımsa sizin.
#
# hamlet Özür dilerim kırdımsa sizin.
#
# hamlet*Özür*dilerim*kırdımsa*sizin**
#
#
#
#
#
#
# *
# Horatio: Özür dileyecek bir şey yok efendim.
#
# horatio: Özür dileyecek bir şey yok efendim.
#
# horatio Özür dileyecek bir şey yok efendim.
#
# horatio*Özür*dileyecek*bir*şey*yok*efendim**
#
#
#
#
#
#
# *
# Hamlet: Olmaz olur mu Horatio, var özürlü bir şey.
#
# hamlet: olmaz olur mu horatio, var özürlü bir şey.
#
# hamlet olmaz olur mu horatio var özürlü bir şey.
#
# hamlet*olmaz*olur*mu*horatio*var*özürlü*bir*şey**
#
#
#
#
#
#
# *
# Bu gece gördüğünüz şeyi kimseye söylemeyeceksiniz.
#
# bu gece gördüğünüz şeyi kimseye söylemeyeceksiniz.
#
# bu gece gördüğünüz şeyi kimseye söylemeyeceksiniz.
#
# bu*gece*gördüğünüz*şeyi*kimseye*söylemeyeceksiniz**
#
#
#
#
#
#
# *
# Marcellus: Söylemeyiz efendimiz.
#
# marcellus: söylemeyiz efendimiz.
#
# marcellus söylemeyiz efendimiz.
#
# marcellus*söylemeyiz*efendimiz**
#
#
#
#
#
#
# *
# Hamlet: Yemin edin.
#
# hamlet: yemin edin.
#
# hamlet yemin edin.
#
# hamlet*yemin*edin**
#
#
#
#
#
#
# *
# Horatio: Yemin ederiz.
#
# horatio: yemin ederiz.
#
# horatio yemin ederiz.
#
# horatio*yemin*ederiz**
#
#
#
#
#
#
# *
# Hamlet: Kılıcınız üzerine yemin edin.
#
# hamlet: kılıcınız üzerine yemin edin.
#
# hamlet kılıcınız üzerine yemin edin.
#
# hamlet*kılıcınız*üzerine*yemin*edin**
#
#
#
#
#
#
# *
# Marcellus: Ettik ya efendimiz.
#
# marcellus: ettik ya efendimiz.
#
# marcellus ettik ya efendimiz.
#
# marcellus*ettik*ya*efendimiz**
#
#
#
#
#
#
# *
# Hamlet: Hayır hayır. Kılıcınız üzerine…
#
# hamlet: hayır hayır. kılıcınız üzerine…
#
# hamlet hayır hayır. kılıcınız üzerine…
#
# hamlet*hayır*hayır**kılıcınız*üzerine…*
#
#
#
#
#
#
# *
# Hayalet: Yemin edin.
#
# hayalet: yemin edin.
#
# hayalet yemin edin.
#
# hayalet*yemin*edin**
#
#
#
#
#
#
# *
# Hamlet: Bak hele, sen de mi öyle diyorsun
#
# hamlet: bak hele, sen de mi öyle diyorsun
#
# hamlet bak hele sen de mi öyle diyorsun
#
# hamlet*bak*hele*sen*de*mi*öyle*diyorsun*
#
#
#
#
#
#
# *
# Duydunuz değil mi bizimkini
#
# duydunuz değil mi bizimkini
#
# duydunuz değil mi bizimkini
#
# duydunuz*değil*mi*bizimkini*
#
#
#
#
#
#
# *
# Hadi yemin edin.
#
# hadi yemin edin.
#
# hadi yemin edin.
#
# hadi*yemin*edin**
#
#
#
#
#
#
# *
# Horatio: Nasıl edelim efendimiz?
#
# horatio: nasıl edelim efendimiz?
#
# horatio nasıl edelim efendimiz
#
# horatio*nasıl*edelim*efendimiz*
#
#
#
#
#
#
# *
# Hamlet: Bu gece gördüğünüzü kimseye söylemeyeceksiniz.
#
# hamlet: bu gece gördüğünüzü kimseye söylemeyeceksiniz.
#
# hamlet bu gece gördüğünüzü kimseye söylemeyeceksiniz.
#
# hamlet*bu*gece*gördüğünüzü*kimseye*söylemeyeceksiniz**
#
#
#
#
#
#
# *
# Kılıcınız üzerine yemin edin.
#
# kılıcınız üzerine yemin edin.
#
# kılıcınız üzerine yemin edin.
#
# kılıcınız*üzerine*yemin*edin**
#
#
#
#
#
#
# *
# Hayalet: Yemin edin.
#
# hayalet: yemin edin.
#
# hayalet yemin edin.
#
# hayalet*yemin*edin**
#
#
#
#
#
#
# *
# Hamlet: Ne duyduğunuzu kimseye söylemek yok.
#
# hamlet: ne duyduğunuzu kimseye söylemek yok.
#
# hamlet ne duyduğunuzu kimseye söylemek yok.
#
# hamlet*ne*duyduğunuzu*kimseye*söylemek*yok**
#
#
#
#
#
#
# *
# Horatio: Ey günler geceler
#
# horatio: ey günler geceler
#
# horatio ey günler geceler
#
# horatio*ey*günler*geceler*
#
#
#
#
#
#
# *
# Böyle şey görülmüş mü hiç!
#
# böyle şey görülmüş mü hiç!
#
# böyle şey görülmüş mü hiç
#
# böyle*şey*görülmüş*mü*hiç*
#
#
#
#
#
#
# *
# Hamlet: Böyle bir şey görmemiş olun siz de.
#
# hamlet: böyle bir şey görmemiş olun siz de.
#
# hamlet böyle bir şey görmemiş olun siz de.
#
# hamlet*böyle*bir*şey*görmemiş*olun*siz*de**
#
#
#
#
#
#
# *
# Kim bilir belki de, bundan böyle, uygunuma gelecek bir süre
#
# kim bilir belki de, bundan böyle, uygunuma gelecek bir süre
#
# kim bilir belki de bundan böyle uygunuma gelecek bir süre
#
# kim*bilir*belki*de*bundan*böyle*uygunuma*gelecek*bir*süre*
#
#
#
#
#
#
# *
# Garip garip haller takınmam.
#
# garip garip haller takınmam.
#
# garip garip haller takınmam.
#
# garip*garip*haller*takınmam**
#
#
#
#
#
#
# *
# Bütün muhabbetimle tanrıya emanet olun!
#
# bütün muhabbetimle tanrıya emanet olun!
#
# bütün muhabbetimle tanrıya emanet olun
#
# bütün*muhabbetimle*tanrıya*emanet*olun*
#
#
#
#
#
#
# *
# Hamlet diye biri varsa, bir yoksul-u biçare,
#
# hamlet diye biri varsa, bir yoksul-u biçare,
#
# hamlet diye biri varsa bir yoksulu biçare
#
# hamlet*diye*biri*varsa*bir*yoksulu*biçare*
#
#
#
#
#
#
# *
# Size sevgisinden başka bir şey sunamaz ki…
#
# size sevgisinden başka bir şey sunamaz ki…
#
# size sevgisinden başka bir şey sunamaz ki…
#
# size*sevgisinden*başka*bir*şey*sunamaz*ki…*
#
#
#
#
#
#
# *
# Çığrından çıkmış bir zaman bu. Ey kör talihim benim!
#
# Çığrından çıkmış bir zaman bu. ey kör talihim benim!
#
# Çığrından çıkmış bir zaman bu. ey kör talihim benim
#
# Çığrından*çıkmış*bir*zaman*bu**ey*kör*talihim*benim*
#
#
#
#
#
#
# *
# Bana düşmez olaydı dünyayı düzeltmek.
#
# bana düşmez olaydı dünyayı düzeltmek.
#
# bana düşmez olaydı dünyayı düzeltmek.
#
# bana*düşmez*olaydı*dünyayı*düzeltmek**
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-f0e11421e11b> in <module>()
#      13     #D, DD, alphabet = count_transitions(data, my_alphabet, {})
#      14     #D, DD, alphabet = count_transitions(data, ascii_alphabet, my2ascii_table)
# ---> 15     D, DD, alphabet = count_transitions(data, tr_alphabet, my2tr_table)
#      16     M = len(alphabet)
#      17     DD[0,0] = 1
#
# <ipython-input-66-063b1b26a7ed> in count_transitions(fpp, alphabet, tab)
#     107     for k in D.keys():
#     108         i = a2i[k[0]]
# --> 109         j = a2i[k[1]]
#     110         DD[i,j] = D[k]
#     111
#
# KeyError: u'\xfc'

# %% [markdown]
# ### Normalized probability table of $p(x_t|x_{t−1})$

# %%
def normalize(A, axis=0):
    Z = np.sum(A, axis=axis,keepdims=True)
    idx = np.where(Z == 0)
    Z[idx] = 1
    return A/Z

local = 'data/'
#local = 'https://dl.dropboxusercontent.com/u/9787379/swe546/data/'

file = 'hamlet_turkce.txt'
data = urlopen(local+file) 
D, DD, alphabet = count_transitions(data, tr_alphabet, my2tr_table)


plt.figure(figsize=(9,9))

T = normalize(DD, axis=1)


plt.imshow(T, interpolation='nearest', vmin=0)
plt.xticks(range(M), alphabet)
plt.yticks(range(M), alphabet)
plt.gca().xaxis.tick_top()

plt.show()
